# %% [markdown]
# # 1. 将文件的脉冲和标记提取出来：raw data

# %%
import json
import os
import numpy as np
from datetime import datetime

# ================= 配置 =================
RAW_DIR = r"./raw"
OUTPUT_DIR = r"./data"
OUTPUT_FILE = os.path.join(OUTPUT_DIR, 'raw_dataset_standardized.npy')

os.makedirs(OUTPUT_DIR, exist_ok=True)
# =======================================

def process_raw_data():
    start_time = datetime.now()
    print(f"开始处理原始数据: {start_time}")

    all_sequences = []  # 存储所有样本的数据
    all_labels = []     # 存储所有样本的标签

    files = [f for f in os.listdir(RAW_DIR) if f.endswith('.json')]
    print(f"找到 {len(files)} 个 JSON 文件")

    for idx, filename in enumerate(files):
        file_path = os.path.join(RAW_DIR, filename)
        
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
        except Exception as e:
            print(f"读取失败 {filename}: {e}")
            continue

        # 1. 处理时间轴，找到 t=0 的索引
        X_time = np.array(data.get("POINT_N_time", []))
        if len(X_time) == 0: continue
        
        first_valid_index = next((i for i, v in enumerate(X_time) if v >= 0), None)
        if first_valid_index is None: continue

        # 2. 解析标签 (invalid_chord)
        invalid_chord = data.get("invalid_chord", "")
        invalid_ids = []
        if isinstance(invalid_chord, str):
            # 处理中文分号等情况
            invalid_chord = invalid_chord.replace('；', ';')
            if invalid_chord in ["all", "all;"]:
                invalid_ids = list(range(1, 12))
            elif invalid_chord != "no" and invalid_chord.strip() != "":
                parts = invalid_chord.split(';')
                invalid_ids = [int(p) for p in parts if p.strip().isdigit()]
        elif isinstance(invalid_chord, int):
            invalid_ids = [invalid_chord]

        # 3. 遍历 11 个通道提取数据
        for ch_i in range(1, 12):
            key = f'POINT_N{ch_i}'
            if key not in data: continue
            
            raw_seq = np.array(data[key])
            
            # 截取 t > 0 的部分
            if len(raw_seq) <= first_valid_index: continue
            valid_seq = raw_seq[first_valid_index:]
            
            # --- 关键步骤：数据标准化 (Standardization) ---
            # 减去均值，除以标准差 (Z-Score Normalization)
            # 加 1e-6 防止除以零
            std_val = np.std(valid_seq)
            mean_val = np.mean(valid_seq)
            if std_val == 0:
                normalized_seq = valid_seq - mean_val # 如果方差为0，这就全是0了
            else:
                normalized_seq = (valid_seq - mean_val) / (std_val + 1e-6)
            
            # 确定标签
            label = 0 if ch_i in invalid_ids else 1
            
            # 为了节省内存，如果数据太长可以降采样 (Optional)
            # 例如：每隔2个点取一个，保留物理特征但减少计算量
            # normalized_seq = normalized_seq[::2] 

            all_sequences.append(normalized_seq.astype(np.float32))
            all_labels.append(label)

        if (idx + 1) % 10 == 0:
            print(f"已处理 {idx + 1}/{len(files)} 个文件...")

    # 保存为 numpy 格式
    # 由于序列长度不一，必须使用 object 数组保存
    print("正在保存数据...")
    data_dict = {
        "sequences": np.array(all_sequences, dtype=object),
        "labels": np.array(all_labels, dtype=np.int64)
    }
    np.save(OUTPUT_FILE, data_dict, allow_pickle=True)
    
    end_time = datetime.now()
    print(f"处理完成。共保存 {len(all_labels)} 个样本。")
    print(f"保存路径: {OUTPUT_FILE}")
    print(f"总耗时: {end_time - start_time}")

if __name__ == "__main__":
    process_raw_data()
# Out:
# 开始处理原始数据: 2025-12-20 00:05:06.055400
# 找到 433 个 JSON 文件
# 已处理 10/433 个文件...
# 已处理 20/433 个文件...
# 已处理 30/433 个文件...
# 已处理 40/433 个文件...
# 已处理 50/433 个文件...
# 已处理 60/433 个文件...
# 已处理 70/433 个文件...
# 已处理 80/433 个文件...
# 已处理 90/433 个文件...
# 已处理 100/433 个文件...
# 已处理 110/433 个文件...
# 已处理 120/433 个文件...
# 已处理 130/433 个文件...
# 已处理 140/433 个文件...
# 已处理 150/433 个文件...
# 已处理 160/433 个文件...
# 已处理 170/433 个文件...
# 已处理 180/433 个文件...
# 已处理 190/433 个文件...
# 已处理 200/433 个文件...
# 已处理 210/433 个文件...
# 已处理 220/433 个文件...
# 已处理 230/433 个文件...
# 已处理 240/433 个文件...
# 已处理 250/433 个文件...
# 已处理 260/433 个文件...
# 已处理 270/433 个文件...
# 已处理 280/433 个文件...
# 已处理 290/433 个文件...
# 已处理 300/433 个文件...
# 已处理 310/433 个文件...
# 已处理 320/433 个文件...
# 已处理 330/433 个文件...
# 已处理 340/433 个文件...
# 已处理 350/433 个文件...
# 已处理 360/433 个文件...
# 已处理 370/433 个文件...
# 已处理 380/433 个文件...
# 已处理 390/433 个文件...
# 已处理 400/433 个文件...
# 已处理 410/433 个文件...
# 已处理 420/433 个文件...
# 已处理 430/433 个文件...
# 正在保存数据...
# 处理完成。共保存 4763 个样本。
# 保存路径: ./data/raw_dataset_standardized.npy
# 总耗时: 0:01:28.882942

# %% [markdown]
# # 2. 将文件的脉冲和标记提取出来：基于Koopman线性化手段

# %%
import json
import os
import numpy as np
from datetime import datetime

# 定义路径
directory_path = r"./raw"
# 输出文件路径
result_path = r'./data/data_koopman_sequence.txt' 

start_time = datetime.now()
print("开始时间：", start_time)

# 确保输出目录存在
os.makedirs(os.path.dirname(result_path), exist_ok=True)

# =======================================================
# 【新增 1】: 预先获取所有 json 文件列表，以便计算总数
# =======================================================
all_json_files = [f for f in os.listdir(directory_path) if f.endswith('.json')]
total_files_count = len(all_json_files)
print(f"--> 目录中检测到 JSON 文件总数: {total_files_count}")

# =======================================================
# 【新增 2】: 初始化样本计数器
# =======================================================
total_samples_generated = 0


def koopman(X):
    # ... (函数体保持不变，为了节省篇幅，此处省略函数内部具体逻辑，与您提供的完全一致) ...
    X = np.array(X)
    num = len(X)
    embedding_dimension = num - 10 
    delay = 1
    hankel_rows = 1
    hankel_row_matrices = []
    
    for i in range(hankel_rows):
        num_rows = len(X) - delay * (embedding_dimension - 1)
        if num_rows <= 0: return []   
        num_cols = delay * embedding_dimension
        hankel_row_matrix = np.zeros((num_rows, num_cols))
        for k in range(num_rows):
            for l in range(embedding_dimension):
                hankel_row_matrix[k, l * delay: (l + 1) * delay] = X[k + l * delay]
        hankel_row_matrices.append(hankel_row_matrix)
    
    hankel = np.vstack(hankel_row_matrices)
    
    try:
        H, S, V = np.linalg.svd(hankel, full_matrices=False)
    except np.linalg.LinAlgError:
        return []

    singular_values_count = 11
    if len(S) < singular_values_count:
        singular_values_count = len(S)

    step = 120
    # 注意：这里依然依赖外部变量 dt_global，请确保下方主循环逻辑正确
    local_dt = 1.0 

    v = np.diag(S[0:singular_values_count]) @ V[0:singular_values_count, :]
    
    dv_dt = np.zeros_like(v)
    for i in range(singular_values_count):
        dv_dt[i, :] = np.gradient(v[i, :], dt_global, edge_order=2)
    
    row_norms_list = []
    limit = embedding_dimension - step
    if limit <= 0: return []

    for i in range(0, limit, 1):
        start = i
        end = start + step
        v_t = dv_dt[:, start:end]
        vv = v[:, start:end]
        try:
            A = v_t @ np.linalg.pinv(vv)
            B = v_t - A @ vv
            row_norms = np.linalg.norm(B, axis=1)
            BB = np.mean(row_norms)
            row_norms_list.append(BB)
        except:
            continue
            
    row_norms_list = np.array(row_norms_list)
    local_maxima_values = []
    window_size = 40
    if len(row_norms_list) > 2 * window_size:
        for i in range(window_size, len(row_norms_list) - window_size):
            window = row_norms_list[i - window_size:i + window_size + 1]
            max_index_in_window = np.argmax(window)
            if max_index_in_window == window_size:
                local_maxima_values.append(window[window_size])
    
    return local_maxima_values


# =======================================================
# 主循环 (修改为使用 enumerate 遍历文件列表)
# =======================================================
for idx, filename in enumerate(all_json_files, 1): # idx 从 1 开始计数
    
    file_start_time = datetime.now()
    
    # 【新增 3】: 打印当前进度 (当前/总数)
    print(f"[{idx}/{total_files_count}] 正在处理: {filename} ...")
    
    data_path = os.path.join(directory_path, filename)
    
    try:
        with open(data_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except Exception as e:
        print(f"  [Error] 读取文件 {filename} 失败: {e}")
        continue

    X_time = np.array(data["POINT_N_time"])
    first_valid_index = next((index for index, value in enumerate(X_time) if value >= 0), None)
    
    if first_valid_index is not None:
        X_time_valid = X_time[first_valid_index:]
        if len(X_time_valid) > 1:
            dt_global = X_time_valid[1] - X_time_valid[0] # 全局变量赋值
        else:
            dt_global = 1.0 
    else:
        print(f"  [Skip] 跳过 {filename}: 无有效时间数据")
        continue

    # 处理无效通道标签
    invalid_chord = data.get("invalid_chord", "")
    invalid_chord_index = []
    if isinstance(invalid_chord, str) and invalid_chord:
        invalid_chord = invalid_chord.replace('；', ';') 
        parts = invalid_chord.split(';')
        invalid_chord_index = [int(p) for p in parts if p.strip().isdigit()]
        
    if invalid_chord == "all" or invalid_chord == "all;":
        invalid_chord_index = list(range(1, 12))
    elif invalid_chord == "no":
        invalid_chord_index = []
    elif isinstance(invalid_chord, (int)) or (isinstance(invalid_chord, str) and invalid_chord.isdigit()):
        invalid_chord_index = [int(invalid_chord)]

    # 遍历 11 个通道
    samples_in_this_file = 0 # 统计当前文件生成的样本数
    
    for i in range(1, 12):
        key = f'POINT_N{i}'
        
        if i in invalid_chord_index:
            label = 0 
        else:
            label = 1 
        
        if key in data and len(data[key]) > first_valid_index:
            raw_series = data[key][first_valid_index:]
            koopman_sequence = koopman(raw_series)
            
            if len(koopman_sequence) > 0:
                sequence_str = ",".join(map(str, koopman_sequence))
                output_line = f"{sequence_str},{label}\n"
                
                with open(result_path, 'a') as file:
                    file.write(output_line)
                
                # 【新增 4】: 累加样本总数
                total_samples_generated += 1
                samples_in_this_file += 1
    
    file_end_time = datetime.now()
    # 打印单个文件的处理耗时和产出
    print(f"  -> 完成。耗时: {file_end_time - file_start_time}, 本文件产出样本: {samples_in_this_file}")

# =======================================================
# 【新增 5】: 程序结束后的汇总统计
# =======================================================
end_time = datetime.now()
total_duration = end_time - start_time

print("\n" + "="*50)
print("程序运行结束")
print(f"结束时间: {end_time}")
print(f"总运行时间: {total_duration}")
print(f"处理文件总数: {idx}/{total_files_count}") # 使用最后的 idx 确保准确
print(f"生成样本总数: {total_samples_generated}")
print(f"结果已保存至: {result_path}")
print("="*50)
# Out:
# 开始时间： 2025-12-21 12:40:30.647976
# --> 目录中检测到 JSON 文件总数: 433
# [1/433] 正在处理: POINTdata_137557.json ...
#   -> 完成。耗时: 0:00:11.545538, 本文件产出样本: 11
# [2/433] 正在处理: POINTdata_78016.json ...
#   -> 完成。耗时: 0:00:10.032780, 本文件产出样本: 11
# [3/433] 正在处理: POINTdata_137691.json ...
#   -> 完成。耗时: 0:00:10.134841, 本文件产出样本: 11
# [4/433] 正在处理: POINTdata_100018.json ...
#   -> 完成。耗时: 0:00:09.922386, 本文件产出样本: 11
# [5/433] 正在处理: POINTdata_106965.json ...
#   -> 完成。耗时: 0:00:13.767173, 本文件产出样本: 11
# [6/433] 正在处理: POINTdata_106318.json ...
#   -> 完成。耗时: 0:00:11.464081, 本文件产出样本: 11
# [7/433] 正在处理: POINTdata_106461.json ...
#   -> 完成。耗时: 0:00:11.256428, 本文件产出样本: 11
# [8/433] 正在处理: POINTdata_77971.json ...
#   -> 完成。耗时: 0:00:10.093045, 本文件产出样本: 11
# [9/433] 正在处理: POINTdata_106477.json ...
#   -> 完成。耗时: 0:00:13.755806, 本文件产出样本: 11
# [10/433] 正在处理: POINTdata_77967.json ...
#   -> 完成。耗时: 0:00:10.156382, 本文件产出样本: 11
# [11/433] 正在处理: POINTdata_79580.json ...
#   -> 完成。耗时: 0:00:09.851890, 本文件产出样本: 11
# [12/433] 正在处理: POINTdata_106498.json ...
#   -> 完成。耗时: 0:00:13.792152, 本文件产出样本: 11
# [13/433] 正在处理: POINTdata_100262.json ...
#   -> 完成。耗时: 0:00:10.341832, 本文件产出样本: 11
# [14/433] 正在处理: POINTdata_78000.json ...
#   -> 完成。耗时: 0:00:10.505316, 本文件产出样本: 11
# [15/433] 正在处理: POINTdata_137687.json ...
#   -> 完成。耗时: 0:00:10.486488, 本文件产出样本: 11
# [16/433] 正在处理: POINTdata_79884.json ...
#   -> 完成。耗时: 0:00:09.852612, 本文件产出样本: 11
# [17/433] 正在处理: POINTdata_106637.json ...
#   -> 完成。耗时: 0:00:14.711813, 本文件产出样本: 11
# [18/433] 正在处理: POINTdata_137756.json ...
#   -> 完成。耗时: 0:00:11.637410, 本文件产出样本: 11
# [19/433] 正在处理: POINTdata_79810.json ...
#   -> 完成。耗时: 0:00:10.177604, 本文件产出样本: 11
# [20/433] 正在处理: POINTdata_106725.json ...
#   -> 完成。耗时: 0:00:13.776594, 本文件产出样本: 11
# [21/433] 正在处理: POINTdata_80218.json ...
#   -> 完成。耗时: 0:00:10.150707, 本文件产出样本: 11
# [22/433] 正在处理: POINTdata_146838.json ...
#   -> 完成。耗时: 0:00:15.916738, 本文件产出样本: 11
# [23/433] 正在处理: POINTdata_58863.json ...
#   -> 完成。耗时: 0:00:10.574696, 本文件产出样本: 11
# [24/433] 正在处理: POINTdata_137644.json ...
#   -> 完成。耗时: 0:00:11.727406, 本文件产出样本: 11
# [25/433] 正在处理: POINTdata_80131.json ...
#   -> 完成。耗时: 0:00:10.162816, 本文件产出样本: 11
# [26/433] 正在处理: POINTdata_100022.json ...
#   -> 完成。耗时: 0:00:10.339905, 本文件产出样本: 11
# [27/433] 正在处理: POINTdata_100188.json ...
#   -> 完成。耗时: 0:00:12.850639, 本文件产出样本: 11
# [28/433] 正在处理: POINTdata_100171.json ...
#   -> 完成。耗时: 0:00:10.121339, 本文件产出样本: 11
# [29/433] 正在处理: POINTdata_100034.json ...
#   -> 完成。耗时: 0:00:09.907728, 本文件产出样本: 11
# [30/433] 正在处理: POINTdata_106334.json ...
#   -> 完成。耗时: 0:00:10.904688, 本文件产出样本: 11
# [31/433] 正在处理: POINTdata_137469.json ...
#   -> 完成。耗时: 0:00:11.050158, 本文件产出样本: 11
# [32/433] 正在处理: POINTdata_99994.json ...
#   -> 完成。耗时: 0:00:09.892784, 本文件产出样本: 11
# [33/433] 正在处理: POINTdata_137740.json ...
#   -> 完成。耗时: 0:00:11.100401, 本文件产出样本: 11
# [34/433] 正在处理: POINTdata_137737.json ...
#   -> 完成。耗时: 0:00:11.045942, 本文件产出样本: 11
# [35/433] 正在处理: POINTdata_79871.json ...
#   -> 完成。耗时: 0:00:09.604101, 本文件产出样本: 11
# [36/433] 正在处理: POINTdata_100014.json ...
#   -> 完成。耗时: 0:00:09.931775, 本文件产出样本: 11
# [37/433] 正在处理: POINTdata_137672.json ...
#   -> 完成。耗时: 0:00:09.671828, 本文件产出样本: 11
# [38/433] 正在处理: POINTdata_106343.json ...
#   -> 完成。耗时: 0:00:14.197990, 本文件产出样本: 11
# [39/433] 正在处理: POINTdata_79826.json ...
#   -> 完成。耗时: 0:00:10.235360, 本文件产出样本: 11
# [40/433] 正在处理: POINTdata_106894.json ...
#   -> 完成。耗时: 0:00:11.322467, 本文件产出样本: 11
# [41/433] 正在处理: POINTdata_106744.json ...
#   -> 完成。耗时: 0:00:14.708305, 本文件产出样本: 11
# [42/433] 正在处理: POINTdata_137776.json ...
#   -> 完成。耗时: 0:00:11.850489, 本文件产出样本: 11
# [43/433] 正在处理: POINTdata_106882.json ...
#   -> 完成。耗时: 0:00:14.801648, 本文件产出样本: 11
# [44/433] 正在处理: POINTdata_79830.json ...
#   -> 完成。耗时: 0:00:10.151321, 本文件产出样本: 11
# [45/433] 正在处理: POINTdata_106494.json ...
#   -> 完成。耗时: 0:00:14.234932, 本文件产出样本: 11
# [46/433] 正在处理: POINTdata_106617.json ...
#   -> 完成。耗时: 0:00:13.787865, 本文件产出样本: 11
# [47/433] 正在处理: POINTdata_106752.json ...
#   -> 完成。耗时: 0:00:14.857601, 本文件产出样本: 11
# [48/433] 正在处理: POINTdata_106302.json ...
#   -> 完成。耗时: 0:00:11.347129, 本文件产出样本: 11
# [49/433] 正在处理: POINTdata_100002.json ...
#   -> 完成。耗时: 0:00:10.477853, 本文件产出样本: 11
# [50/433] 正在处理: POINTdata_137664.json ...
#   -> 完成。耗时: 0:00:09.864483, 本文件产出样本: 11
# [51/433] 正在处理: POINTdata_137473.json ...
#   -> 完成。耗时: 0:00:11.167923, 本文件产出样本: 11
# [52/433] 正在处理: POINTdata_137648.json ...
#   -> 完成。耗时: 0:00:11.105625, 本文件产出样本: 11
# [53/433] 正在处理: POINTdata_100184.json ...
#   -> 完成。耗时: 0:00:12.540679, 本文件产出样本: 11
# [54/433] 正在处理: POINTdata_137561.json ...
#   -> 完成。耗时: 0:00:11.839784, 本文件产出样本: 11
# [55/433] 正在处理: POINTdata_77005.json ...
#   -> 完成。耗时: 0:00:10.092665, 本文件产出样本: 11
# [56/433] 正在处理: POINTdata_100192.json ...
#   -> 完成。耗时: 0:00:12.403922, 本文件产出样本: 11
# [57/433] 正在处理: POINTdata_146822.json ...
#   -> 完成。耗时: 0:00:15.679766, 本文件产出样本: 11
# [58/433] 正在处理: POINTdata_77951.json ...
#   -> 完成。耗时: 0:00:10.089236, 本文件产出样本: 11
# [59/433] 正在处理: POINTdata_99977.json ...
#   -> 完成。耗时: 0:00:10.218933, 本文件产出样本: 11
# [60/433] 正在处理: POINTdata_100203.json ...
#   -> 完成。耗时: 0:00:10.556235, 本文件产出样本: 11
# [61/433] 正在处理: POINTdata_99998.json ...
#   -> 完成。耗时: 0:00:10.499731, 本文件产出样本: 11
# [62/433] 正在处理: POINTdata_99976.json ...
#   -> 完成。耗时: 0:00:10.553372, 本文件产出样本: 11
# [63/433] 正在处理: POINTdata_106769.json ...
#   -> 完成。耗时: 0:00:14.926772, 本文件产出样本: 11
# [64/433] 正在处理: POINTdata_106339.json ...
#   -> 完成。耗时: 0:00:11.536750, 本文件产出样本: 11
# [65/433] 正在处理: POINTdata_100202.json ...
#   -> 完成。耗时: 0:00:10.417101, 本文件产出样本: 11
# [66/433] 正在处理: POINTdata_99999.json ...
#   -> 完成。耗时: 0:00:10.445019, 本文件产出样本: 11
# [67/433] 正在处理: POINTdata_77950.json ...
#   -> 完成。耗时: 0:00:10.191437, 本文件产出样本: 11
# [68/433] 正在处理: POINTdata_80203.json ...
#   -> 完成。耗时: 0:00:10.183312, 本文件产出样本: 11
# [69/433] 正在处理: POINTdata_137576.json ...
#   -> 完成。耗时: 0:00:11.749155, 本文件产出样本: 11
# [70/433] 正在处理: POINTdata_100193.json ...
#   -> 完成。耗时: 0:00:08.036506, 本文件产出样本: 11
# [71/433] 正在处理: POINTdata_146835.json ...
#   -> 完成。耗时: 0:00:15.404681, 本文件产出样本: 11
# [72/433] 正在处理: POINTdata_106728.json ...
#   -> 完成。耗时: 0:00:13.394150, 本文件产出样本: 11
# [73/433] 正在处理: POINTdata_58881.json ...
#   -> 完成。耗时: 0:00:10.207831, 本文件产出样本: 11
# [74/433] 正在处理: POINTdata_137560.json ...
#   -> 完成。耗时: 0:00:11.870010, 本文件产出样本: 11
# [75/433] 正在处理: POINTdata_100185.json ...
#   -> 完成。耗时: 0:00:12.279576, 本文件产出样本: 11
# [76/433] 正在处理: POINTdata_77946.json ...
#   -> 完成。耗时: 0:00:10.199730, 本文件产出样本: 11
# [77/433] 正在处理: POINTdata_106905.json ...
#   -> 完成。耗时: 0:00:15.625268, 本文件产出样本: 11
# [78/433] 正在处理: POINTdata_146819.json ...
#   -> 完成。耗时: 0:00:15.561139, 本文件产出样本: 11
# [79/433] 正在处理: POINTdata_100003.json ...
#   -> 完成。耗时: 0:00:10.517427, 本文件产出样本: 11
# [80/433] 正在处理: POINTdata_137665.json ...
#   -> 完成。耗时: 0:00:10.069343, 本文件产出样本: 11
# [81/433] 正在处理: POINTdata_106753.json ...
#   -> 完成。耗时: 0:00:14.836162, 本文件产出样本: 11
# [82/433] 正在处理: POINTdata_137777.json ...
#   -> 完成。耗时: 0:00:11.904519, 本文件产出样本: 11
# [83/433] 正在处理: POINTdata_106315.json ...
#   -> 完成。耗时: 0:00:11.551430, 本文件产出样本: 11
# [84/433] 正在处理: POINTdata_106745.json ...
#   -> 完成。耗时: 0:00:14.662029, 本文件产出样本: 11
# [85/433] 正在处理: POINTdata_79827.json ...
#   -> 完成。耗时: 0:00:10.132216, 本文件产出样本: 11
# [86/433] 正在处理: POINTdata_137761.json ...
#   -> 完成。耗时: 0:00:11.892223, 本文件产出样本: 11
# [87/433] 正在处理: POINTdata_137736.json ...
#   -> 完成。耗时: 0:00:11.900658, 本文件产出样本: 11
# [88/433] 正在处理: POINTdata_100015.json ...
#   -> 完成。耗时: 0:00:10.396755, 本文件产出样本: 11
# [89/433] 正在处理: POINTdata_80043.json ...
#   -> 完成。耗时: 0:00:10.251764, 本文件产出样本: 11
# [90/433] 正在处理: POINTdata_137673.json ...
#   -> 完成。耗时: 0:00:10.159147, 本文件产出样本: 11
# [91/433] 正在处理: POINTdata_79807.json ...
#   -> 完成。耗时: 0:00:09.662306, 本文件产出样本: 11
# [92/433] 正在处理: POINTdata_137741.json ...
#   -> 完成。耗时: 0:00:11.652827, 本文件产出样本: 11
# [93/433] 正在处理: POINTdata_106335.json ...
#   -> 完成。耗时: 0:00:11.557703, 本文件产出样本: 11
# [94/433] 正在处理: POINTdata_100170.json ...
#   -> 完成。耗时: 0:00:10.441362, 本文件产出样本: 11
# [95/433] 正在处理: POINTdata_100035.json ...
#   -> 完成。耗时: 0:00:10.598650, 本文件产出样本: 11
# [96/433] 正在处理: POINTdata_100023.json ...
#   -> 完成。耗时: 0:00:10.513955, 本文件产出样本: 11
# [97/433] 正在处理: POINTdata_100189.json ...
#   -> 完成。耗时: 0:00:12.762517, 本文件产出样本: 11
# [98/433] 正在处理: POINTdata_137700.json ...
#   -> 完成。耗时: 0:00:09.889184, 本文件产出样本: 11
# [99/433] 正在处理: POINTdata_80219.json ...
#   -> 完成。耗时: 0:00:09.729801, 本文件产出样本: 11
# [100/433] 正在处理: POINTdata_137583.json ...
#   -> 完成。耗时: 0:00:11.166826, 本文件产出样本: 11
# [101/433] 正在处理: POINTdata_80188.json ...
#   -> 完成。耗时: 0:00:09.674477, 本文件产出样本: 11
# [102/433] 正在处理: POINTdata_137757.json ...
#   -> 完成。耗时: 0:00:11.554775, 本文件产出样本: 11
# [103/433] 正在处理: POINTdata_106909.json ...
#   -> 完成。耗时: 0:00:11.092835, 本文件产出样本: 11
# [104/433] 正在处理: POINTdata_79811.json ...
#   -> 完成。耗时: 0:00:10.182657, 本文件产出样本: 11
# [105/433] 正在处理: POINTdata_106773.json ...
#   -> 完成。耗时: 0:00:16.004176, 本文件产出样本: 11
# [106/433] 正在处理: POINTdata_106323.json ...
#   -> 完成。耗时: 0:00:11.591956, 本文件产出样本: 11
# [107/433] 正在处理: POINTdata_99983.json ...
#   -> 完成。耗时: 0:00:10.406613, 本文件产出样本: 11
# [108/433] 正在处理: POINTdata_137686.json ...
#   -> 完成。耗时: 0:00:10.089633, 本文件产出样本: 11
# [109/433] 正在处理: POINTdata_77874.json ...
#   -> 完成。耗时: 0:00:10.168517, 本文件产出样本: 11
# [110/433] 正在处理: POINTdata_137669.json ...
#   -> 完成。耗时: 0:00:10.102882, 本文件产出样本: 11
# [111/433] 正在处理: POINTdata_100263.json ...
#   -> 完成。耗时: 0:00:10.011625, 本文件产出样本: 11
# [112/433] 正在处理: POINTdata_106476.json ...
#   -> 完成。耗时: 0:00:13.700394, 本文件产出样本: 11
# [113/433] 正在处理: POINTdata_146907.json ...
#   -> 完成。耗时: 0:00:15.837459, 本文件产出样本: 11
# [114/433] 正在处理: POINTdata_77970.json ...
#   -> 完成。耗时: 0:00:10.231367, 本文件产出样本: 11
# [115/433] 正在处理: POINTdata_106876.json ...
#   -> 完成。耗时: 0:00:14.286927, 本文件产出样本: 11
# [116/433] 正在处理: POINTdata_106749.json ...
#   -> 完成。耗时: 0:00:14.926507, 本文件产出样本: 11
# [117/433] 正在处理: POINTdata_106319.json ...
#   -> 完成。耗时: 0:00:11.613115, 本文件产出样本: 11
# [118/433] 正在处理: POINTdata_100019.json ...
#   -> 完成。耗时: 0:00:10.698125, 本文件产出样本: 11
# [119/433] 正在处理: POINTdata_137556.json ...
#   -> 完成。耗时: 0:00:11.651377, 本文件产出样本: 11
# [120/433] 正在处理: POINTdata_78017.json ...
#   -> 完成。耗时: 0:00:10.286417, 本文件产出样本: 11
# [121/433] 正在处理: POINTdata_100012.json ...
#   -> 完成。耗时: 0:00:10.463682, 本文件产出样本: 11
# [122/433] 正在处理: POINTdata_137674.json ...
#   -> 完成。耗时: 0:00:09.682509, 本文件产出样本: 11
# [123/433] 正在处理: POINTdata_58853.json ...
#   -> 完成。耗时: 0:00:09.958171, 本文件产出样本: 11
# [124/433] 正在处理: POINTdata_79820.json ...
#   -> 完成。耗时: 0:00:10.257520, 本文件产出样本: 11
# [125/433] 正在处理: POINTdata_137766.json ...
#   -> 完成。耗时: 0:00:09.224827, 本文件产出样本: 11
# [126/433] 正在处理: POINTdata_106312.json ...
#   -> 完成。耗时: 0:00:11.367718, 本文件产出样本: 11
# [127/433] 正在处理: POINTdata_106492.json ...
#   -> 完成。耗时: 0:00:13.777545, 本文件产出样本: 11
# [128/433] 正在处理: POINTdata_106754.json ...
#   -> 完成。耗时: 0:00:14.757778, 本文件产出样本: 11
# [129/433] 正在处理: POINTdata_100004.json ...
#   -> 完成。耗时: 0:00:10.479397, 本文件产出样本: 11
# [130/433] 正在处理: POINTdata_80117.json ...
#   -> 完成。耗时: 0:00:05.586577, 本文件产出样本: 11
# [131/433] 正在处理: POINTdata_137662.json ...
#   -> 完成。耗时: 0:00:09.673213, 本文件产出样本: 11
# [132/433] 正在处理: POINTdata_100268.json ...
#   -> 完成。耗时: 0:00:10.005349, 本文件产出样本: 11
# [133/433] 正在处理: POINTdata_80029.json ...
#   -> 完成。耗时: 0:00:09.603549, 本文件产出样本: 11
# [134/433] 正在处理: POINTdata_137475.json ...
#   -> 完成。耗时: 0:00:10.495710, 本文件产出样本: 11
# [135/433] 正在处理: POINTdata_80245.json ...
#   -> 完成。耗时: 0:00:09.623777, 本文件产出样本: 11
# [136/433] 正在处理: POINTdata_99988.json ...
#   -> 完成。耗时: 0:00:09.924254, 本文件产出样本: 11
# [137/433] 正在处理: POINTdata_77015.json ...
#   -> 完成。耗时: 0:00:09.548920, 本文件产出样本: 11
# [138/433] 正在处理: POINTdata_100182.json ...
#   -> 完成。耗时: 0:00:11.908565, 本文件产出样本: 11
# [139/433] 正在处理: POINTdata_100028.json ...
#   -> 完成。耗时: 0:00:09.951264, 本文件产出样本: 11
# [140/433] 正在处理: POINTdata_137588.json ...
#   -> 完成。耗时: 0:00:11.102517, 本文件产出样本: 11
# [141/433] 正在处理: POINTdata_58869.json ...
#   -> 完成。耗时: 0:00:09.719683, 本文件产出样本: 11
# [142/433] 正在处理: POINTdata_106390.json ...
#   -> 完成。耗时: 0:00:13.379357, 本文件产出样本: 11
# [143/433] 正在处理: POINTdata_77003.json ...
#   -> 完成。耗时: 0:00:10.147262, 本文件产出样本: 11
# [144/433] 正在处理: POINTdata_137658.json ...
#   -> 完成。耗时: 0:00:11.615239, 本文件产出样本: 11
# [145/433] 正在处理: POINTdata_106386.json ...
#   -> 完成。耗时: 0:00:13.787446, 本文件产出样本: 11
# [146/433] 正在处理: POINTdata_137571.json ...
#   -> 完成。耗时: 0:00:11.712824, 本文件产出样本: 11
# [147/433] 正在处理: POINTdata_58890.json ...
#   -> 完成。耗时: 0:00:10.162389, 本文件产出样本: 11
# [148/433] 正在处理: POINTdata_137551.json ...
#   -> 完成。耗时: 0:00:11.857298, 本文件产出样本: 11
# [149/433] 正在处理: POINTdata_79251.json ...
#   -> 完成。耗时: 0:00:09.717582, 本文件产出样本: 11
# [150/433] 正在处理: POINTdata_77998.json ...
#   -> 完成。耗时: 0:00:09.711760, 本文件产出样本: 11
# [151/433] 正在处理: POINTdata_106467.json ...
#   -> 完成。耗时: 0:00:10.927249, 本文件产出样本: 11
# [152/433] 正在处理: POINTdata_106488.json ...
#   -> 完成。耗时: 0:00:13.560880, 本文件产出样本: 11
# [153/433] 正在处理: POINTdata_146845.json ...
#   -> 完成。耗时: 0:00:15.466611, 本文件产出样本: 11
# [154/433] 正在处理: POINTdata_106308.json ...
#   -> 完成。耗时: 0:00:11.523596, 本文件产出样本: 11
# [155/433] 正在处理: POINTdata_106758.json ...
#   -> 完成。耗时: 0:00:14.647917, 本文件产出样本: 11
# [156/433] 正在处理: POINTdata_106471.json ...
#   -> 完成。耗时: 0:00:13.846991, 本文件产出样本: 11
# [157/433] 正在处理: POINTdata_79569.json ...
#   -> 完成。耗时: 0:00:10.113645, 本文件产出样本: 11
# [158/433] 正在处理: POINTdata_100264.json ...
#   -> 完成。耗时: 0:00:10.343147, 本文件产出样本: 11
# [159/433] 正在处理: POINTdata_137547.json ...
#   -> 完成。耗时: 0:00:11.975685, 本文件产出样本: 11
# [160/433] 正在处理: POINTdata_79247.json ...
#   -> 完成。耗时: 0:00:10.097090, 本文件产出样本: 11
# [161/433] 正在处理: POINTdata_77873.json ...
#   -> 完成。耗时: 0:00:10.205749, 本文件产出样本: 11
# [162/433] 正在处理: POINTdata_100008.json ...
#   -> 完成。耗时: 0:00:10.455871, 本文件产出样本: 11
# [163/433] 正在处理: POINTdata_79882.json ...
#   -> 完成。耗时: 0:00:09.776212, 本文件产出样本: 11
# [164/433] 正在处理: POINTdata_137479.json ...
#   -> 完成。耗时: 0:00:11.838321, 本文件产出样本: 11
# [165/433] 正在处理: POINTdata_99984.json ...
#   -> 完成。耗时: 0:00:10.497200, 本文件产出样本: 11
# [166/433] 正在处理: POINTdata_106631.json ...
#   -> 完成。耗时: 0:00:14.759184, 本文件产出样本: 11
# [167/433] 正在处理: POINTdata_137750.json ...
#   -> 完成。耗时: 0:00:11.569197, 本文件产出样本: 11
# [168/433] 正在处理: POINTdata_58865.json ...
#   -> 完成。耗时: 0:00:10.236472, 本文件产出样本: 11
# [169/433] 正在处理: POINTdata_100024.json ...
#   -> 完成。耗时: 0:00:10.465771, 本文件产出样本: 11
# [170/433] 正在处理: POINTdata_106735.json ...
#   -> 完成。耗时: 0:00:13.928735, 本文件产出样本: 11
# [171/433] 正在处理: POINTdata_100177.json ...
#   -> 完成。耗时: 0:00:10.522143, 本文件产出样本: 11
# [172/433] 正在处理: POINTdata_80121.json ...
#   -> 完成。耗时: 0:00:12.432749, 本文件产出样本: 11
# [173/433] 正在处理: POINTdata_100198.json ...
#   -> 完成。耗时: 0:00:10.667464, 本文件产出样本: 11
# [174/433] 正在处理: POINTdata_99992.json ...
#   -> 完成。耗时: 0:00:10.010291, 本文件产出样本: 11
# [175/433] 正在处理: POINTdata_137480.json ...
#   -> 完成。耗时: 0:00:11.176684, 本文件产出样本: 11
# [176/433] 正在处理: POINTdata_80199.json ...
#   -> 完成。耗时: 0:00:10.064082, 本文件产出样本: 11
# [177/433] 正在处理: POINTdata_137746.json ...
#   -> 完成。耗时: 0:00:11.888636, 本文件产出样本: 11
# [178/433] 正在处理: POINTdata_137747.json ...
#   -> 完成。耗时: 0:00:11.337950, 本文件产出样本: 11
# [179/433] 正在处理: POINTdata_106763.json ...
#   -> 完成。耗时: 0:00:14.726643, 本文件产出样本: 11
# [180/433] 正在处理: POINTdata_99993.json ...
#   -> 完成。耗时: 0:00:10.436044, 本文件产出样本: 11
# [181/433] 正在处理: POINTdata_137655.json ...
#   -> 完成。耗时: 0:00:11.171305, 本文件产出样本: 11
# [182/433] 正在处理: POINTdata_100176.json ...
#   -> 完成。耗时: 0:00:10.510163, 本文件产出样本: 11
# [183/433] 正在处理: POINTdata_106734.json ...
#   -> 完成。耗时: 0:00:13.906255, 本文件产出样本: 11
# [184/433] 正在处理: POINTdata_100025.json ...
#   -> 完成。耗时: 0:00:10.585942, 本文件产出样本: 11
# [185/433] 正在处理: POINTdata_58864.json ...
#   -> 完成。耗时: 0:00:10.072455, 本文件产出样本: 11
# [186/433] 正在处理: POINTdata_137585.json ...
#   -> 完成。耗时: 0:00:11.976381, 本文件产出样本: 11
# [187/433] 正在处理: POINTdata_137751.json ...
#   -> 完成。耗时: 0:00:11.742530, 本文件产出样本: 11
# [188/433] 正在处理: POINTdata_137478.json ...
#   -> 完成。耗时: 0:00:11.166409, 本文件产出样本: 11
# [189/433] 正在处理: POINTdata_77366.json ...
#   -> 完成。耗时: 0:00:09.644366, 本文件产出样本: 11
# [190/433] 正在处理: POINTdata_99985.json ...
#   -> 完成。耗时: 0:00:10.000281, 本文件产出样本: 11
# [191/433] 正在处理: POINTdata_106630.json ...
#   -> 完成。耗时: 0:00:09.589483, 本文件产出样本: 11
# [192/433] 正在处理: POINTdata_77872.json ...
#   -> 完成。耗时: 0:00:09.656659, 本文件产出样本: 11
# [193/433] 正在处理: POINTdata_100009.json ...
#   -> 完成。耗时: 0:00:09.946169, 本文件产出样本: 11
# [194/433] 正在处理: POINTdata_79883.json ...
#   -> 完成。耗时: 0:00:10.202712, 本文件产出样本: 11
# [195/433] 正在处理: POINTdata_77937.json ...
#   -> 完成。耗时: 0:00:09.730519, 本文件产出样本: 11
# [196/433] 正在处理: POINTdata_100265.json ...
#   -> 完成。耗时: 0:00:09.833035, 本文件产出样本: 11
# [197/433] 正在处理: POINTdata_137546.json ...
#   -> 完成。耗时: 0:00:11.073112, 本文件产出样本: 11
# [198/433] 正在处理: POINTdata_106470.json ...
#   -> 完成。耗时: 0:00:13.503537, 本文件产出样本: 11
# [199/433] 正在处理: POINTdata_77960.json ...
#   -> 完成。耗时: 0:00:10.209568, 本文件产出样本: 11
# [200/433] 正在处理: POINTdata_131580.json ...
#   -> 完成。耗时: 0:00:09.983608, 本文件产出样本: 11
# [201/433] 正在处理: POINTdata_106309.json ...
#   -> 完成。耗时: 0:00:11.601081, 本文件产出样本: 11
# [202/433] 正在处理: POINTdata_106759.json ...
#   -> 完成。耗时: 0:00:14.953535, 本文件产出样本: 11
# [203/433] 正在处理: POINTdata_77999.json ...
#   -> 完成。耗时: 0:00:10.205194, 本文件产出样本: 11
# [204/433] 正在处理: POINTdata_106466.json ...
#   -> 完成。耗时: 0:00:11.342346, 本文件产出样本: 11
# [205/433] 正在处理: POINTdata_106489.json ...
#   -> 完成。耗时: 0:00:14.933545, 本文件产出样本: 11
# [206/433] 正在处理: POINTdata_106295.json ...
#   -> 完成。耗时: 0:00:11.524673, 本文件产出样本: 11
# [207/433] 正在处理: POINTdata_100204.json ...
#   -> 完成。耗时: 0:00:10.594717, 本文件产出样本: 11
# [208/433] 正在处理: POINTdata_80205.json ...
#   -> 完成。耗时: 0:00:10.123731, 本文件产出样本: 11
# [209/433] 正在处理: POINTdata_106738.json ...
#   -> 完成。耗时: 0:00:14.085704, 本文件产出样本: 11
# [210/433] 正在处理: POINTdata_58891.json ...
#   -> 完成。耗时: 0:00:10.658985, 本文件产出样本: 11
# [211/433] 正在处理: POINTdata_100253.json ...
#   -> 完成。耗时: 0:00:10.693051, 本文件产出样本: 11
# [212/433] 正在处理: POINTdata_80213.json ...
#   -> 完成。耗时: 0:00:09.893062, 本文件产出样本: 11
# [213/433] 正在处理: POINTdata_137589.json ...
#   -> 完成。耗时: 0:00:11.162506, 本文件产出样本: 11
# [214/433] 正在处理: POINTdata_58887.json ...
#   -> 完成。耗时: 0:00:09.763837, 本文件产出样本: 11
# [215/433] 正在处理: POINTdata_77014.json ...
#   -> 完成。耗时: 0:00:09.722659, 本文件产出样本: 11
# [216/433] 正在处理: POINTdata_100183.json ...
#   -> 完成。耗时: 0:00:12.588445, 本文件产出样本: 11
# [217/433] 正在处理: POINTdata_100029.json ...
#   -> 完成。耗时: 0:00:10.570748, 本文件产出样本: 11
# [218/433] 正在处理: POINTdata_137474.json ...
#   -> 完成。耗时: 0:00:11.436380, 本文件产出样本: 11
# [219/433] 正在处理: POINTdata_99989.json ...
#   -> 完成。耗时: 0:00:10.328206, 本文件产出样本: 11
# [220/433] 正在处理: POINTdata_80182.json ...
#   -> 完成。耗时: 0:00:10.438652, 本文件产出样本: 11
# [221/433] 正在处理: POINTdata_100269.json ...
#   -> 完成。耗时: 0:00:10.600049, 本文件产出样本: 11
# [222/433] 正在处理: POINTdata_100005.json ...
#   -> 完成。耗时: 0:00:09.958616, 本文件产出样本: 11
# [223/433] 正在处理: POINTdata_137663.json ...
#   -> 完成。耗时: 0:00:10.385706, 本文件产出样本: 11
# [224/433] 正在处理: POINTdata_106305.json ...
#   -> 完成。耗时: 0:00:11.506750, 本文件产出样本: 11
# [225/433] 正在处理: POINTdata_106885.json ...
#   -> 完成。耗时: 0:00:15.029324, 本文件产出样本: 11
# [226/433] 正在处理: POINTdata_106313.json ...
#   -> 完成。耗时: 0:00:11.507726, 本文件产出样本: 11
# [227/433] 正在处理: POINTdata_106893.json ...
#   -> 完成。耗时: 0:00:11.643475, 本文件产出样本: 11
# [228/433] 正在处理: POINTdata_137767.json ...
#   -> 完成。耗时: 0:00:09.316327, 本文件产出样本: 11
# [229/433] 正在处理: POINTdata_79572.json ...
#   -> 完成。耗时: 0:00:09.771575, 本文件产出样本: 11
# [230/433] 正在处理: POINTdata_106485.json ...
#   -> 完成。耗时: 0:00:13.774186, 本文件产出样本: 11
# [231/433] 正在处理: POINTdata_106344.json ...
#   -> 完成。耗时: 0:00:15.007395, 本文件产出样本: 11
# [232/433] 正在处理: POINTdata_58852.json ...
#   -> 完成。耗时: 0:00:10.319424, 本文件产出样本: 11
# [233/433] 正在处理: POINTdata_100013.json ...
#   -> 完成。耗时: 0:00:10.564621, 本文件产出样本: 11
# [234/433] 正在处理: POINTdata_137675.json ...
#   -> 完成。耗时: 0:00:10.294363, 本文件产出样本: 11
# [235/433] 正在处理: POINTdata_106629.json ...
#   -> 完成。耗时: 0:00:14.775248, 本文件产出样本: 11
# [236/433] 正在处理: POINTdata_100207.json ...
#   -> 完成。耗时: 0:00:10.469316, 本文件产出样本: 11
# [237/433] 正在处理: POINTdata_106296.json ...
#   -> 完成。耗时: 0:00:11.124247, 本文件产出样本: 11
# [238/433] 正在处理: POINTdata_137748.json ...
#   -> 完成。耗时: 0:00:11.194373, 本文件产出样本: 11
# [239/433] 正在处理: POINTdata_58892.json ...
#   -> 完成。耗时: 0:00:09.732530, 本文件产出样本: 11
# [240/433] 正在处理: POINTdata_100196.json ...
#   -> 完成。耗时: 0:00:10.006707, 本文件产出样本: 11
# [241/433] 正在处理: POINTdata_100179.json ...
#   -> 完成。耗时: 0:00:10.057005, 本文件产出样本: 11
# [242/433] 正在处理: POINTdata_106392.json ...
#   -> 完成。耗时: 0:00:13.560996, 本文件产出样本: 11
# [243/433] 正在处理: POINTdata_58884.json ...
#   -> 完成。耗时: 0:00:10.233285, 本文件产出样本: 11
# [244/433] 正在处理: POINTdata_137565.json ...
#   -> 完成。耗时: 0:00:11.472810, 本文件产出样本: 11
# [245/433] 正在处理: POINTdata_80139.json ...
#   -> 完成。耗时: 0:00:10.090053, 本文件产出样本: 11
# [246/433] 正在处理: POINTdata_77017.json ...
#   -> 完成。耗时: 0:00:10.233707, 本文件产出样本: 11
# [247/433] 正在处理: POINTdata_137477.json ...
#   -> 完成。耗时: 0:00:11.667885, 本文件产出样本: 11
# [248/433] 正在处理: POINTdata_79818.json ...
#   -> 完成。耗时: 0:00:10.249193, 本文件产出样本: 11
# [249/433] 正在处理: POINTdata_79249.json ...
#   -> 完成。耗时: 0:00:10.159231, 本文件产出样本: 11
# [250/433] 正在处理: POINTdata_137660.json ...
#   -> 完成。耗时: 0:00:11.789344, 本文件产出样本: 11
# [251/433] 正在处理: POINTdata_80115.json ...
#   -> 完成。耗时: 0:00:10.245285, 本文件产出样本: 11
# [252/433] 正在处理: POINTdata_100006.json ...
#   -> 完成。耗时: 0:00:10.172104, 本文件产出样本: 11
# [253/433] 正在处理: POINTdata_106490.json ...
#   -> 完成。耗时: 0:00:15.575459, 本文件产出样本: 11
# [254/433] 正在处理: POINTdata_137772.json ...
#   -> 完成。耗时: 0:00:09.552547, 本文件产出样本: 11
# [255/433] 正在处理: POINTdata_79567.json ...
#   -> 完成。耗时: 0:00:10.269940, 本文件产出样本: 11
# [256/433] 正在处理: POINTdata_106310.json ...
#   -> 完成。耗时: 0:00:11.302610, 本文件产出样本: 11
# [257/433] 正在处理: POINTdata_79571.json ...
#   -> 完成。耗时: 0:00:09.984487, 本文件产出样本: 11
# [258/433] 正在处理: POINTdata_137764.json ...
#   -> 完成。耗时: 0:00:09.349125, 本文件产出样本: 11
# [259/433] 正在处理: POINTdata_58851.json ...
#   -> 完成。耗时: 0:00:10.198206, 本文件产出样本: 11
# [260/433] 正在处理: POINTdata_137733.json ...
#   -> 完成。耗时: 0:00:11.789915, 本文件产出样本: 11
# [261/433] 正在处理: POINTdata_100010.json ...
#   -> 完成。耗时: 0:00:10.619092, 本文件产出样本: 11
# [262/433] 正在处理: POINTdata_79875.json ...
#   -> 完成。耗时: 0:00:09.866710, 本文件产出样本: 11
# [263/433] 正在处理: POINTdata_137744.json ...
#   -> 完成。耗时: 0:00:11.218065, 本文件产出样本: 11
# [264/433] 正在处理: POINTdata_99990.json ...
#   -> 完成。耗时: 0:00:10.605568, 本文件产出样本: 11
# [265/433] 正在处理: POINTdata_106760.json ...
#   -> 完成。耗时: 0:00:15.129610, 本文件产出样本: 11
# [266/433] 正在处理: POINTdata_100030.json ...
#   -> 完成。耗时: 0:00:10.567512, 本文件产出样本: 11
# [267/433] 正在处理: POINTdata_137656.json ...
#   -> 完成。耗时: 0:00:11.782171, 本文件产出样本: 11
# [268/433] 正在处理: POINTdata_100175.json ...
#   -> 完成。耗时: 0:00:10.330836, 本文件产出样本: 11
# [269/433] 正在处理: POINTdata_137590.json ...
#   -> 完成。耗时: 0:00:12.000327, 本文件产出样本: 11
# [270/433] 正在处理: POINTdata_100026.json ...
#   -> 完成。耗时: 0:00:10.399757, 本文件产出样本: 11
# [271/433] 正在处理: POINTdata_58888.json ...
#   -> 完成。耗时: 0:00:10.111310, 本文件产出样本: 11
# [272/433] 正在处理: POINTdata_137586.json ...
#   -> 完成。耗时: 0:00:11.959997, 本文件产出样本: 11
# [273/433] 正在处理: POINTdata_137752.json ...
#   -> 完成。耗时: 0:00:11.301616, 本文件产出样本: 11
# [274/433] 正在处理: POINTdata_79814.json ...
#   -> 完成。耗时: 0:00:09.948646, 本文件产出样本: 11
# [275/433] 正在处理: POINTdata_77365.json ...
#   -> 完成。耗时: 0:00:10.211740, 本文件产出样本: 11
# [276/433] 正在处理: POINTdata_99986.json ...
#   -> 完成。耗时: 0:00:10.469386, 本文件产出样本: 11
# [277/433] 正在处理: POINTdata_80119.json ...
#   -> 完成。耗时: 0:00:11.788055, 本文件产出样本: 11
# [278/433] 正在处理: POINTdata_77871.json ...
#   -> 完成。耗时: 0:00:10.280632, 本文件产出样本: 11
# [279/433] 正在处理: POINTdata_78004.json ...
#   -> 完成。耗时: 0:00:10.312147, 本文件产出样本: 11
# [280/433] 正在处理: POINTdata_137768.json ...
#   -> 完成。耗时: 0:00:09.315632, 本文件产出样本: 11
# [281/433] 正在处理: POINTdata_106465.json ...
#   -> 完成。耗时: 0:00:11.546016, 本文件产出样本: 11
# [282/433] 正在处理: POINTdata_146914.json ...
#   -> 完成。耗时: 0:00:16.072106, 本文件产出样本: 11
# [283/433] 正在处理: POINTdata_137553.json ...
#   -> 完成。耗时: 0:00:11.746889, 本文件产出样本: 11
# [284/433] 正在处理: POINTdata_100270.json ...
#   -> 完成。耗时: 0:00:10.528076, 本文件产出样本: 11
# [285/433] 正在处理: POINTdata_79252.json ...
#   -> 完成。耗时: 0:00:10.327830, 本文件产出样本: 11
# [286/433] 正在处理: POINTdata_100271.json ...
#   -> 完成。耗时: 0:00:10.700574, 本文件产出样本: 11
# [287/433] 正在处理: POINTdata_79878.json ...
#   -> 完成。耗时: 0:00:10.519686, 本文件产出样本: 11
# [288/433] 正在处理: POINTdata_137694.json ...
#   -> 完成。耗时: 0:00:10.586214, 本文件产出样本: 11
# [289/433] 正在处理: POINTdata_146915.json ...
#   -> 完成。耗时: 0:00:16.323153, 本文件产出样本: 11
# [290/433] 正在处理: POINTdata_106464.json ...
#   -> 完成。耗时: 0:00:11.738718, 本文件产出样本: 11
# [291/433] 正在处理: POINTdata_146846.json ...
#   -> 完成。耗时: 0:00:15.903198, 本文件产出样本: 11
# [292/433] 正在处理: POINTdata_77962.json ...
#   -> 完成。耗时: 0:00:09.936938, 本文件产出样本: 11
# [293/433] 正在处理: POINTdata_106472.json ...
#   -> 完成。耗时: 0:00:13.891636, 本文件产出样本: 11
# [294/433] 正在处理: POINTdata_80118.json ...
#   -> 完成。耗时: 0:00:10.173170, 本文件产出样本: 11
# [295/433] 正在处理: POINTdata_106632.json ...
#   -> 完成。耗时: 0:00:14.707471, 本文件产出样本: 11
# [296/433] 正在处理: POINTdata_77364.json ...
#   -> 完成。耗时: 0:00:10.319347, 本文件产出样本: 11
# [297/433] 正在处理: POINTdata_99987.json ...
#   -> 完成。耗时: 0:00:10.263363, 本文件产出样本: 11
# [298/433] 正在处理: POINTdata_137753.json ...
#   -> 完成。耗时: 0:00:11.164513, 本文件产出样本: 11
# [299/433] 正在处理: POINTdata_79815.json ...
#   -> 完成。耗时: 0:00:09.714678, 本文件产出样本: 11
# [300/433] 正在处理: POINTdata_137568.json ...
#   -> 完成。耗时: 0:00:11.854141, 本文件产出样本: 11
# [301/433] 正在处理: POINTdata_58889.json ...
#   -> 完成。耗时: 0:00:10.258669, 本文件产出样本: 11
# [302/433] 正在处理: POINTdata_58866.json ...
#   -> 完成。耗时: 0:00:09.883971, 本文件产出样本: 11
# [303/433] 正在处理: POINTdata_137587.json ...
#   -> 完成。耗时: 0:00:12.487309, 本文件产出样本: 11
# [304/433] 正在处理: POINTdata_100031.json ...
#   -> 完成。耗时: 0:00:10.588322, 本文件产出样本: 11
# [305/433] 正在处理: POINTdata_137657.json ...
#   -> 完成。耗时: 0:00:11.727538, 本文件产出样本: 11
# [306/433] 正在处理: POINTdata_100174.json ...
#   -> 完成。耗时: 0:00:10.963324, 本文件产出样本: 11
# [307/433] 正在处理: POINTdata_106624.json ...
#   -> 完成。耗时: 0:00:14.458951, 本文件产出样本: 11
# [308/433] 正在处理: POINTdata_106761.json ...
#   -> 完成。耗时: 0:00:15.455437, 本文件产出样本: 11
# [309/433] 正在处理: POINTdata_137745.json ...
#   -> 完成。耗时: 0:00:12.278757, 本文件产出样本: 11
# [310/433] 正在处理: POINTdata_80030.json ...
#   -> 完成。耗时: 0:00:10.149366, 本文件产出样本: 11
# [311/433] 正在处理: POINTdata_106487.json ...
#   -> 完成。耗时: 0:00:13.902996, 本文件产出样本: 11
# [312/433] 正在处理: POINTdata_106468.json ...
#   -> 完成。耗时: 0:00:11.600586, 本文件产出样本: 11
# [313/433] 正在处理: POINTdata_79570.json ...
#   -> 完成。耗时: 0:00:09.966177, 本文件产出样本: 11
# [314/433] 正在处理: POINTdata_77997.json ...
#   -> 完成。耗时: 0:00:10.195562, 本文件产出样本: 11
# [315/433] 正在处理: POINTdata_106311.json ...
#   -> 完成。耗时: 0:00:11.823135, 本文件产出样本: 11
# [316/433] 正在处理: POINTdata_106491.json ...
#   -> 完成。耗时: 0:00:14.124213, 本文件产出样本: 11
# [317/433] 正在处理: POINTdata_137773.json ...
#   -> 完成。耗时: 0:00:09.439645, 本文件产出样本: 11
# [318/433] 正在处理: POINTdata_79566.json ...
#   -> 完成。耗时: 0:00:10.553959, 本文件产出样本: 11
# [319/433] 正在处理: POINTdata_137661.json ...
#   -> 完成。耗时: 0:00:12.118249, 本文件产出样本: 11
# [320/433] 正在处理: POINTdata_100007.json ...
#   -> 完成。耗时: 0:00:10.862445, 本文件产出样本: 11
# [321/433] 正在处理: POINTdata_79248.json ...
#   -> 完成。耗时: 0:00:10.409616, 本文件产出样本: 11
# [322/433] 正在处理: POINTdata_137548.json ...
#   -> 完成。耗时: 0:00:12.003018, 本文件产出样本: 11
# [323/433] 正在处理: POINTdata_137476.json ...
#   -> 完成。耗时: 0:00:11.731908, 本文件产出样本: 11
# [324/433] 正在处理: POINTdata_100181.json ...
#   -> 完成。耗时: 0:00:10.170914, 本文件产出样本: 11
# [325/433] 正在处理: POINTdata_77016.json ...
#   -> 完成。耗时: 0:00:10.291034, 本文件产出样本: 11
# [326/433] 正在处理: POINTdata_137564.json ...
#   -> 完成。耗时: 0:00:11.941605, 本文件产出样本: 11
# [327/433] 正在处理: POINTdata_100197.json ...
#   -> 完成。耗时: 0:00:10.658239, 本文件产出样本: 11
# [328/433] 正在处理: POINTdata_100178.json ...
#   -> 完成。耗时: 0:00:10.575820, 本文件产出样本: 11
# [329/433] 正在处理: POINTdata_106385.json ...
#   -> 完成。耗时: 0:00:11.180159, 本文件产出样本: 11
# [330/433] 正在处理: POINTdata_77954.json ...
#   -> 完成。耗时: 0:00:09.784716, 本文件产出样本: 11
# [331/433] 正在处理: POINTdata_99972.json ...
#   -> 完成。耗时: 0:00:09.995676, 本文件产出样本: 11
# [332/433] 正在处理: POINTdata_80250.json ...
#   -> 完成。耗时: 0:00:09.698716, 本文件产出样本: 11
# [333/433] 正在处理: POINTdata_79804.json ...
#   -> 完成。耗时: 0:00:09.720069, 本文件产出样本: 11
# [334/433] 正在处理: POINTdata_137742.json ...
#   -> 完成。耗时: 0:00:11.137476, 本文件产出样本: 11
# [335/433] 正在处理: POINTdata_106623.json ...
#   -> 完成。耗时: 0:00:13.847986, 本文件产出样本: 11
# [336/433] 正在处理: POINTdata_99996.json ...
#   -> 完成。耗时: 0:00:10.476187, 本文件产出样本: 11
# [337/433] 正在处理: POINTdata_99979.json ...
#   -> 完成。耗时: 0:00:10.180769, 本文件产出样本: 11
# [338/433] 正在处理: POINTdata_106766.json ...
#   -> 完成。耗时: 0:00:11.574663, 本文件产出样本: 11
# [339/433] 正在处理: POINTdata_100036.json ...
#   -> 完成。耗时: 0:00:10.430318, 本文件产出样本: 11
# [340/433] 正在处理: POINTdata_137650.json ...
#   -> 完成。耗时: 0:00:11.463427, 本文件产出样本: 11
# [341/433] 正在处理: POINTdata_100173.json ...
#   -> 完成。耗时: 0:00:10.641764, 本文件产出样本: 11
# [342/433] 正在处理: POINTdata_100020.json ...
#   -> 完成。耗时: 0:00:10.440389, 本文件产出样本: 11
# [343/433] 正在处理: POINTdata_137580.json ...
#   -> 完成。耗时: 0:00:11.179861, 本文件产出样本: 11
# [344/433] 正在处理: POINTdata_106727.json ...
#   -> 完成。耗时: 0:00:13.959047, 本文件产出样本: 11
# [345/433] 正在处理: POINTdata_79812.json ...
#   -> 完成。耗时: 0:00:10.143550, 本文件产出样本: 11
# [346/433] 正在处理: POINTdata_77363.json ...
#   -> 完成。耗时: 0:00:09.800724, 本文件产出样本: 11
# [347/433] 正在处理: POINTdata_99980.json ...
#   -> 完成。耗时: 0:00:10.094581, 本文件产出样本: 11
# [348/433] 正在处理: POINTdata_106770.json ...
#   -> 完成。耗时: 0:00:15.033870, 本文件产出样本: 11
# [349/433] 正在处理: POINTdata_106320.json ...
#   -> 完成。耗时: 0:00:11.562689, 本文件产出样本: 11
# [350/433] 正在处理: POINTdata_100260.json ...
#   -> 完成。耗时: 0:00:10.662228, 本文件产出样本: 11
# [351/433] 正在处理: POINTdata_137543.json ...
#   -> 完成。耗时: 0:00:11.688691, 本文件产出样本: 11
# [352/433] 正在处理: POINTdata_77965.json ...
#   -> 完成。耗时: 0:00:09.896696, 本文件产出样本: 11
# [353/433] 正在处理: POINTdata_137778.json ...
#   -> 完成。耗时: 0:00:11.926149, 本文件产出样本: 11
# [354/433] 正在处理: POINTdata_106475.json ...
#   -> 完成。耗时: 0:00:13.763909, 本文件产出样本: 11
# [355/433] 正在处理: POINTdata_106619.json ...
#   -> 完成。耗时: 0:00:14.057985, 本文件产出样本: 11
# [356/433] 正在处理: POINTdata_137693.json ...
#   -> 完成。耗时: 0:00:10.241286, 本文件产出样本: 11
# [357/433] 正在处理: POINTdata_106967.json ...
#   -> 完成。耗时: 0:00:13.874986, 本文件产出样本: 11
# [358/433] 正在处理: POINTdata_137739.json ...
#   -> 完成。耗时: 0:00:11.874732, 本文件产出样本: 11
# [359/433] 正在处理: POINTdata_80220.json ...
#   -> 完成。耗时: 0:00:10.289487, 本文件产出样本: 11
# [360/433] 正在处理: POINTdata_137555.json ...
#   -> 完成。耗时: 0:00:11.372236, 本文件产出样本: 11
# [361/433] 正在处理: POINTdata_99975.json ...
#   -> 完成。耗时: 0:00:10.099946, 本文件产出样本: 11
# [362/433] 正在处理: POINTdata_79808.json ...
#   -> 完成。耗时: 0:00:09.800605, 本文件产出样本: 11
# [363/433] 正在处理: POINTdata_77953.json ...
#   -> 完成。耗时: 0:00:09.715532, 本文件产出样本: 11
# [364/433] 正在处理: POINTdata_58894.json ...
#   -> 完成。耗时: 0:00:09.752005, 本文件产出样本: 11
# [365/433] 正在处理: POINTdata_80200.json ...
#   -> 完成。耗时: 0:00:09.691511, 本文件产出样本: 11
# [366/433] 正在处理: POINTdata_100190.json ...
#   -> 完成。耗时: 0:00:12.776030, 本文件产出样本: 11
# [367/433] 正在处理: POINTdata_100186.json ...
#   -> 完成。耗时: 0:00:12.592242, 本文件产出样本: 11
# [368/433] 正在处理: POINTdata_77011.json ...
#   -> 完成。耗时: 0:00:10.122567, 本文件产出样本: 11
# [369/433] 正在处理: POINTdata_137471.json ...
#   -> 完成。耗时: 0:00:12.023964, 本文件产出样本: 11
# [370/433] 正在处理: POINTdata_137758.json ...
#   -> 完成。耗时: 0:00:11.531128, 本文件产出样本: 11
# [371/433] 正在处理: POINTdata_137666.json ...
#   -> 完成。耗时: 0:00:09.984559, 本文件产出样本: 11
# [372/433] 正在处理: POINTdata_79865.json ...
#   -> 完成。耗时: 0:00:10.195083, 本文件产出样本: 11
# [373/433] 正在处理: POINTdata_100000.json ...
#   -> 完成。耗时: 0:00:10.523337, 本文件产出样本: 11
# [374/433] 正在处理: POINTdata_80113.json ...
#   -> 完成。耗时: 0:00:09.965394, 本文件产出样本: 11
# [375/433] 正在处理: POINTdata_106496.json ...
#   -> 完成。耗时: 0:00:13.911794, 本文件产出样本: 11
# [376/433] 正在处理: POINTdata_77969.json ...
#   -> 完成。耗时: 0:00:10.293437, 本文件产出样本: 11
# [377/433] 正在处理: POINTdata_106880.json ...
#   -> 完成。耗时: 0:00:13.870059, 本文件产出样本: 11
# [378/433] 正在处理: POINTdata_106316.json ...
#   -> 完成。耗时: 0:00:11.638210, 本文件产出样本: 11
# [379/433] 正在处理: POINTdata_77355.json ...
#   -> 完成。耗时: 0:00:09.904532, 本文件产出样本: 11
# [380/433] 正在处理: POINTdata_106480.json ...
#   -> 完成。耗时: 0:00:13.755712, 本文件产出样本: 11
# [381/433] 正在处理: POINTdata_106879.json ...
#   -> 完成。耗时: 0:00:13.804260, 本文件产出样本: 11
# [382/433] 正在处理: POINTdata_106341.json ...
#   -> 完成。耗时: 0:00:15.358236, 本文件产出样本: 11
# [383/433] 正在处理: POINTdata_137670.json ...
#   -> 完成。耗时: 0:00:10.283538, 本文件产出样本: 11
# [384/433] 正在处理: POINTdata_137735.json ...
#   -> 完成。耗时: 0:00:11.896740, 本文件产出样本: 11
# [385/433] 正在处理: POINTdata_100016.json ...
#   -> 完成。耗时: 0:00:11.043617, 本文件产出样本: 11
# [386/433] 正在处理: POINTdata_137671.json ...
#   -> 完成。耗时: 0:00:10.140566, 本文件产出样本: 11
# [387/433] 正在处理: POINTdata_137734.json ...
#   -> 完成。耗时: 0:00:12.143109, 本文件产出样本: 11
# [388/433] 正在处理: POINTdata_100017.json ...
#   -> 完成。耗时: 0:00:10.904663, 本文件产出样本: 11
# [389/433] 正在处理: POINTdata_106340.json ...
#   -> 完成。耗时: 0:00:11.837980, 本文件产出样本: 11
# [390/433] 正在处理: POINTdata_137558.json ...
#   -> 完成。耗时: 0:00:12.362256, 本文件产出样本: 11
# [391/433] 正在处理: POINTdata_106481.json ...
#   -> 完成。耗时: 0:00:14.177345, 本文件产出样本: 11
# [392/433] 正在处理: POINTdata_106878.json ...
#   -> 完成。耗时: 0:00:15.316470, 本文件产出样本: 11
# [393/433] 正在处理: POINTdata_79825.json ...
#   -> 完成。耗时: 0:00:10.619981, 本文件产出样本: 11
# [394/433] 正在处理: POINTdata_106317.json ...
#   -> 完成。耗时: 0:00:11.840251, 本文件产出样本: 11
# [395/433] 正在处理: POINTdata_137775.json ...
#   -> 完成。耗时: 0:00:09.788531, 本文件产出样本: 11
# [396/433] 正在处理: POINTdata_106881.json ...
#   -> 完成。耗时: 0:00:15.344656, 本文件产出样本: 11
# [397/433] 正在处理: POINTdata_106301.json ...
#   -> 完成。耗时: 0:00:12.057500, 本文件产出样本: 11
# [398/433] 正在处理: POINTdata_137688.json ...
#   -> 完成。耗时: 0:00:10.135218, 本文件产出样本: 11
# [399/433] 正在处理: POINTdata_100001.json ...
#   -> 完成。耗时: 0:00:10.083374, 本文件产出样本: 11
# [400/433] 正在处理: POINTdata_79864.json ...
#   -> 完成。耗时: 0:00:09.786277, 本文件产出样本: 11
# [401/433] 正在处理: POINTdata_137759.json ...
#   -> 完成。耗时: 0:00:10.800595, 本文件产出样本: 11
# [402/433] 正在处理: POINTdata_137470.json ...
#   -> 完成。耗时: 0:00:11.175122, 本文件产出样本: 11
# [403/433] 正在处理: POINTdata_100187.json ...
#   -> 完成。耗时: 0:00:12.680297, 本文件产出样本: 11
# [404/433] 正在处理: POINTdata_77010.json ...
#   -> 完成。耗时: 0:00:10.197005, 本文件产出样本: 11
# [405/433] 正在处理: POINTdata_137562.json ...
#   -> 完成。耗时: 0:00:11.862266, 本文件产出样本: 11
# [406/433] 正在处理: POINTdata_146837.json ...
#   -> 完成。耗时: 0:00:15.761117, 本文件产出样本: 11
# [407/433] 正在处理: POINTdata_80128.json ...
#   -> 完成。耗时: 0:00:06.811274, 本文件产出样本: 11
# [408/433] 正在处理: POINTdata_58895.json ...
#   -> 完成。耗时: 0:00:10.254566, 本文件产出样本: 11
# [409/433] 正在处理: POINTdata_79809.json ...
#   -> 完成。耗时: 0:00:10.105897, 本文件产出样本: 11
# [410/433] 正在处理: POINTdata_77952.json ...
#   -> 完成。耗时: 0:00:10.372654, 本文件产出样本: 11
# [411/433] 正在处理: POINTdata_99974.json ...
#   -> 完成。耗时: 0:00:10.682299, 本文件产出样本: 11
# [412/433] 正在处理: POINTdata_137692.json ...
#   -> 完成。耗时: 0:00:10.356891, 本文件产出样本: 11
# [413/433] 正在处理: POINTdata_137738.json ...
#   -> 完成。耗时: 0:00:11.837789, 本文件产出样本: 11
# [414/433] 正在处理: POINTdata_77358.json ...
#   -> 完成。耗时: 0:00:10.176952, 本文件产出样本: 11
# [415/433] 正在处理: POINTdata_77972.json ...
#   -> 完成。耗时: 0:00:10.297168, 本文件产出样本: 11
# [416/433] 正在处理: POINTdata_106462.json ...
#   -> 完成。耗时: 0:00:11.147287, 本文件产出样本: 11
# [417/433] 正在处理: POINTdata_106618.json ...
#   -> 完成。耗时: 0:00:13.889723, 本文件产出样本: 11
# [418/433] 正在处理: POINTdata_106474.json ...
#   -> 完成。耗时: 0:00:13.660898, 本文件产出样本: 11
# [419/433] 正在处理: POINTdata_100261.json ...
#   -> 完成。耗时: 0:00:10.702473, 本文件产出样本: 11
# [420/433] 正在处理: POINTdata_99981.json ...
#   -> 完成。耗时: 0:00:10.547686, 本文件产出样本: 11
# [421/433] 正在处理: POINTdata_106634.json ...
#   -> 完成。耗时: 0:00:16.109969, 本文件产出样本: 11
# [422/433] 正在处理: POINTdata_137755.json ...
#   -> 完成。耗时: 0:00:11.938560, 本文件产出样本: 11
# [423/433] 正在处理: POINTdata_79813.json ...
#   -> 完成。耗时: 0:00:11.977200, 本文件产出样本: 11
# [424/433] 正在处理: POINTdata_58860.json ...
#   -> 完成。耗时: 0:00:11.774982, 本文件产出样本: 11
# [425/433] 正在处理: POINTdata_106726.json ...
#   -> 完成。耗时: 0:00:15.754625, 本文件产出样本: 11
# [426/433] 正在处理: POINTdata_100021.json ...
#   -> 完成。耗时: 0:00:11.655474, 本文件产出样本: 11
# [427/433] 正在处理: POINTdata_137578.json ...
#   -> 完成。耗时: 0:00:12.601043, 本文件产出样本: 11
# [428/433] 正在处理: POINTdata_100037.json ...
#   -> 完成。耗时: 0:00:10.677307, 本文件产出样本: 11
# [429/433] 正在处理: POINTdata_100172.json ...
#   -> 完成。耗时: 0:00:10.982972, 本文件产出样本: 11
# [430/433] 正在处理: POINTdata_106622.json ...
#   -> 完成。耗时: 0:00:14.186640, 本文件产出样本: 11
# [431/433] 正在处理: POINTdata_99997.json ...
#   -> 完成。耗时: 0:00:10.603795, 本文件产出样本: 11
# [432/433] 正在处理: POINTdata_99978.json ...
#   -> 完成。耗时: 0:00:10.587177, 本文件产出样本: 11
# [433/433] 正在处理: POINTdata_137743.json ...
#   -> 完成。耗时: 0:00:11.922517, 本文件产出样本: 11
#
# ==================================================
# 程序运行结束
# 结束时间: 2025-12-21 14:02:32.658523
# 总运行时间: 1:22:02.010547
# 处理文件总数: 433/433
# 生成样本总数: 4763
# 结果已保存至: ./data/data_koopman_sequence.txt
# ==================================================

# %% [markdown]
# # 3. 基于Koopman并只提取几个特征

# %%
import json
import os
import numpy as np
from datetime import datetime
from scipy.stats import skew, kurtosis
from sklearn.linear_model import LinearRegression

# 定义路径
directory_path = r"./raw"
# features_path = r'D:\\Ising\\Ising-CiShuJu\\马金源新代码-20250407\\代码\\result\\result_koopman_3.txt'
result_path = r'./data/data_koopman_6.txt'


start_time = datetime.now()
print("开始时间：", start_time)

def koopman(X):

    X = np.array(X)
    embedding_dimension = num-10
    delay = 1
    hankel_rows = 1
    hankel_row_matrices = []
    for i in range(hankel_rows):
        num_rows = len(X) - delay * (embedding_dimension - 1)
        num_cols = delay * embedding_dimension
        hankel_row_matrix = np.zeros((num_rows, num_cols))
        for k in range(num_rows):
            for l in range(embedding_dimension):
                hankel_row_matrix[k, l * delay: (l + 1) * delay] = X[k + l * delay]
        hankel_row_matrices.append(hankel_row_matrix)
    hankel = np.vstack(hankel_row_matrices)
    H, S, V = np.linalg.svd(hankel)
    singular_values_count = 11
    step = 120
    v = np.diag(S[0:singular_values_count]) @ V[0:singular_values_count, :]
    dv_dt = np.zeros_like(v)
    for i in range(singular_values_count):
        dv_dt[i, :] = np.gradient(v[i, :], dt, edge_order=2)
    dv_dt = np.array(dv_dt)
    row_norms_list = []
    col_norms_list = []
    for i in range(0, embedding_dimension - step, 1):
        start = i
        end = start + step
        v_t = dv_dt[:, start:end]
        vv = v[:, start:end]
        A = v_t @ np.linalg.pinv(vv)
        col_norms = np.linalg.norm(A, axis=0)
        AA = np.mean(col_norms)
        B = v_t - A @ vv
        row_norms = np.linalg.norm(B, axis=1)
        BB = np.mean(row_norms)
        col_norms_list.append(AA)
        row_norms_list.append(BB)
    row_norms_list = np.array(row_norms_list)
    local_maxima_values = []
    local_maxima_indices = []
    local_maxima_times = []
    local_maxima_xdatas = []
    real_times = []
    window_size = 40
    for i in range(window_size, len(row_norms_list) - window_size):
        window = row_norms_list[i - window_size:i + window_size + 1]
        max_index_in_window = np.argmax(window)
        if max_index_in_window == window_size:
            local_maxima_values.append(window[window_size])
            local_maxima_indices.append(i)
            local_maxima_times.append(t[i])
            local_maxima_xdatas.append(X[i])
    return local_maxima_values


for filename in os.listdir(directory_path):
    file_time = datetime.now()
    if filename.endswith('.json'):
        print("一个文件开始：",file_time)
        data_path = os.path.join(directory_path, filename)
        with open(data_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        X_time = np.array(data["POINT_N_time"])
        first_valid_index = next((index for index, value in enumerate(X_time) if value >= 0), None)
        if first_valid_index is not None:
            X_time = X_time[first_valid_index:]
        num = len(X_time)
        t = np.linspace(X_time[0], X_time[-1], num)
        dt = t[1] - t[0]

        invalid_chord = data.get("invalid_chord", "")
        invalid_chord_index = []
        if isinstance(invalid_chord, str) and invalid_chord:
            invalid_chord_index = [int(index) for index in invalid_chord.split(';') if index.isdigit()]
        if invalid_chord == "all" or invalid_chord == "all;":
            invalid_chord_index = list(range(1, 12))
        elif invalid_chord == "no":
            invalid_chord_index = []
        elif isinstance(invalid_chord, (int, str)) and str(invalid_chord).isdigit():
            invalid_chord_index = [int(invalid_chord)]

        for i in range(1,12):
            features = []
            result = []
            key = f'POINT_N{i}'
            if i in invalid_chord_index:
                label = 0
            else:
                label = 1
            koopman_data = koopman(data[key][first_valid_index:])
            mean = np.mean(koopman_data)
            std = np.std(koopman_data)
            max_val = np.max(koopman_data)
            min_val = np.min(koopman_data)
            skewness = skew(koopman_data)
            kurt = kurtosis(koopman_data)


            # features.append([f"文件名{filename}", key, mean, std, min_val, max_val, skewness, kurt, label])
            result.append([mean, std, min_val, max_val, skewness, kurt, label])


            with open(result_path, 'a') as file:
                for re in result:
                    file.write(','.join(str(x).strip('[]') for x in result) + '\n')

            # with open(features_path, 'a') as file:
            #     for result in features:
            #         file.write(','.join(map(str, result)) + '\n')
        filend_time = datetime.now()
        print("一个文件结束：",filend_time)
        print("一个文件的运行时间为：", filend_time-file_time)
end_time = datetime.now()
print("程序结束：",end_time)
print("程序运行时间", end_time-start_time)

# %%
import json
import os
import numpy as np
from datetime import datetime
from scipy.stats import skew, kurtosis
# from sklearn.linear_model import LinearRegression # 未使用，暂时注释掉以保持整洁

# 定义路径
directory_path = r"./raw"
# features_path = r'...' # 原代码注释掉的部分保留
result_path = r'./data/data_koopman_6.txt'

start_time = datetime.now()
print("开始时间：", start_time)

# 确保输出目录存在
os.makedirs(os.path.dirname(result_path), exist_ok=True)

# =======================================================
# 【新增 1】: 获取总文件数以便计算进度
# =======================================================
all_files = [f for f in os.listdir(directory_path) if f.endswith('.json')]
total_files_count = len(all_files)
print(f"目录中检测到 JSON 文件总数: {total_files_count}")

# =======================================================
# 【新增 2】: 初始化总样本计数器
# =======================================================
total_samples_generated = 0


def koopman(X):
    # 注意：为了兼容原代码逻辑，这里依然依赖外部变量 num, dt 等
    # 在实际工程中建议将其作为参数传入 def koopman(X, dt):
    
    X = np.array(X)
    # 重新计算当前 X 的长度，防止外部 num 与 X 不一致导致索引越界
    current_num = len(X)
    embedding_dimension = current_num - 10
    
    delay = 1
    hankel_rows = 1
    hankel_row_matrices = []
    
    for i in range(hankel_rows):
        num_rows = len(X) - delay * (embedding_dimension - 1)
        
        # 增加安全检查
        if num_rows <= 0:
            return []
            
        num_cols = delay * embedding_dimension
        hankel_row_matrix = np.zeros((num_rows, num_cols))
        for k in range(num_rows):
            for l in range(embedding_dimension):
                hankel_row_matrix[k, l * delay: (l + 1) * delay] = X[k + l * delay]
        hankel_row_matrices.append(hankel_row_matrix)
        
    hankel = np.vstack(hankel_row_matrices)
    
    try:
        H, S, V = np.linalg.svd(hankel, full_matrices=False) # 优化速度
    except np.linalg.LinAlgError:
        return []

    singular_values_count = 11
    if len(S) < singular_values_count:
        singular_values_count = len(S)
        
    step = 120
    
    v = np.diag(S[0:singular_values_count]) @ V[0:singular_values_count, :]
    
    dv_dt = np.zeros_like(v)
    # 注意：dt 依赖外部循环中的定义
    for i in range(singular_values_count):
        dv_dt[i, :] = np.gradient(v[i, :], dt, edge_order=2)
    
    dv_dt = np.array(dv_dt)
    
    row_norms_list = []
    # col_norms_list = [] 
    
    limit = embedding_dimension - step
    if limit <= 0: return []

    for i in range(0, limit, 1):
        start = i
        end = start + step
        v_t = dv_dt[:, start:end]
        vv = v[:, start:end]
        
        try:
            A = v_t @ np.linalg.pinv(vv)
            # col_norms = np.linalg.norm(A, axis=0)
            # AA = np.mean(col_norms)
            
            B = v_t - A @ vv
            row_norms = np.linalg.norm(B, axis=1)
            BB = np.mean(row_norms)
            
            # col_norms_list.append(AA)
            row_norms_list.append(BB)
        except:
            continue
            
    row_norms_list = np.array(row_norms_list)
    local_maxima_values = []
    
    window_size = 40
    if len(row_norms_list) > 2 * window_size:
        for i in range(window_size, len(row_norms_list) - window_size):
            window = row_norms_list[i - window_size:i + window_size + 1]
            max_index_in_window = np.argmax(window)
            if max_index_in_window == window_size:
                local_maxima_values.append(window[window_size])
            
    return local_maxima_values


# =======================================================
# 主循环 (使用 enumerate 显示进度)
# =======================================================
for idx, filename in enumerate(all_files, 1): # idx 从 1 开始
    
    file_time = datetime.now()
    # 【新增 3】: 打印进度信息
    print(f"[{idx}/{total_files_count}] 正在处理文件：{filename} (开始时间: {file_time})")
    
    data_path = os.path.join(directory_path, filename)
    
    try:
        with open(data_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except Exception as e:
        print(f"  [Error] 读取文件失败: {e}")
        continue

    X_time = np.array(data.get("POINT_N_time", [])) # 使用 get 防止 key 不存在报错
    
    # 找到第一个非负时间点
    if len(X_time) == 0:
        continue
        
    first_valid_index = next((index for index, value in enumerate(X_time) if value >= 0), None)
    
    if first_valid_index is not None:
        X_time = X_time[first_valid_index:]
        num = len(X_time)
        if num < 2: continue # 数据太短无法计算 dt
        
        t = np.linspace(X_time[0], X_time[-1], num)
        dt = t[1] - t[0]
    else:
        continue # 没有有效时间点

    invalid_chord = data.get("invalid_chord", "")
    invalid_chord_index = []
    if isinstance(invalid_chord, str) and invalid_chord:
        # 兼容中文分号等情况
        invalid_chord = invalid_chord.replace('；', ';')
        parts = invalid_chord.split(';')
        invalid_chord_index = [int(index) for index in parts if index.strip().isdigit()]
        
    if invalid_chord == "all" or invalid_chord == "all;":
        invalid_chord_index = list(range(1, 12))
    elif invalid_chord == "no":
        invalid_chord_index = []
    elif isinstance(invalid_chord, (int)) or (isinstance(invalid_chord, str) and invalid_chord.isdigit()):
        invalid_chord_index = [int(invalid_chord)]

    # 统计本文件内生成的样本数
    samples_in_this_file = 0

    for i in range(1, 12):
        # features = [] # 原代码未使用，注释掉
        result = []
        key = f'POINT_N{i}'
        
        if i in invalid_chord_index:
            label = 0
        else:
            label = 1
            
        if key in data and len(data[key]) > first_valid_index:
            try:
                raw_data = data[key][first_valid_index:]
                # 确保数据长度足够进行 embedding
                if len(raw_data) < 20: continue 
                
                koopman_data = koopman(raw_data)
                
                if len(koopman_data) == 0:
                    continue
                
                mean = np.mean(koopman_data)
                std = np.std(koopman_data)
                max_val = np.max(koopman_data)
                min_val = np.min(koopman_data)
                skewness = skew(koopman_data)
                kurt = kurtosis(koopman_data)

                # features.append(...)
                
                # 这里保持你的逻辑，虽然 result 列表每次循环都会重置，append 了一行数据
                result.append([mean, std, min_val, max_val, skewness, kurt, label])
                
                # 【新增 4】: 累加计数
                total_samples_generated += 1
                samples_in_this_file += 1

            except Exception as e:
                print(f"  [Warning] 通道 {i} 处理出错: {e}")
                continue

        # 写入文件
        if result:
            with open(result_path, 'a') as file:
                for re in result:
                    # 简化写入逻辑，直接 join
                    file.write(','.join(str(x) for x in re) + '\n')

    filend_time = datetime.now()
    print(f"  -> 文件结束。耗时：{filend_time - file_time}。本文件产出样本数：{samples_in_this_file}")

# =======================================================
# 【新增 5】: 最终汇总报告
# =======================================================
end_time = datetime.now()
total_duration = end_time - start_time

print("\n" + "="*50)
print("程序运行结束")
print(f"结束时间: {end_time}")
print(f"总运行时间: {total_duration}")
print(f"处理文件总数: {total_files_count}")
print(f"生成样本总数: {total_samples_generated}")
print(f"结果保存路径: {result_path}")
print("="*50)
# Out:
# 开始时间： 2025-12-21 15:03:13.429808
# 目录中检测到 JSON 文件总数: 433
# [1/433] 正在处理文件：POINTdata_137557.json (开始时间: 2025-12-21 15:03:13.432742)
#   -> 文件结束。耗时：0:00:11.427501。本文件产出样本数：11
# [2/433] 正在处理文件：POINTdata_78016.json (开始时间: 2025-12-21 15:03:24.860312)
#   -> 文件结束。耗时：0:00:09.823003。本文件产出样本数：11
# [3/433] 正在处理文件：POINTdata_137691.json (开始时间: 2025-12-21 15:03:34.683378)
#   -> 文件结束。耗时：0:00:09.913073。本文件产出样本数：11
# [4/433] 正在处理文件：POINTdata_100018.json (开始时间: 2025-12-21 15:03:44.596518)
#   -> 文件结束。耗时：0:00:10.116039。本文件产出样本数：11
# [5/433] 正在处理文件：POINTdata_106965.json (开始时间: 2025-12-21 15:03:54.712624)
#   -> 文件结束。耗时：0:00:13.592872。本文件产出样本数：11
# [6/433] 正在处理文件：POINTdata_106318.json (开始时间: 2025-12-21 15:04:08.305561)
#   -> 文件结束。耗时：0:00:11.188843。本文件产出样本数：11
# [7/433] 正在处理文件：POINTdata_106461.json (开始时间: 2025-12-21 15:04:19.494474)
#   -> 文件结束。耗时：0:00:11.153164。本文件产出样本数：11
# [8/433] 正在处理文件：POINTdata_77971.json (开始时间: 2025-12-21 15:04:30.647699)
#   -> 文件结束。耗时：0:00:09.798153。本文件产出样本数：11
# [9/433] 正在处理文件：POINTdata_106477.json (开始时间: 2025-12-21 15:04:40.445924)
#   -> 文件结束。耗时：0:00:13.396093。本文件产出样本数：11
# [10/433] 正在处理文件：POINTdata_77967.json (开始时间: 2025-12-21 15:04:53.842087)
#   -> 文件结束。耗时：0:00:09.992535。本文件产出样本数：11
# [11/433] 正在处理文件：POINTdata_79580.json (开始时间: 2025-12-21 15:05:03.834686)
#   -> 文件结束。耗时：0:00:09.734851。本文件产出样本数：11
# [12/433] 正在处理文件：POINTdata_106498.json (开始时间: 2025-12-21 15:05:13.569603)
#   -> 文件结束。耗时：0:00:13.483622。本文件产出样本数：11
# [13/433] 正在处理文件：POINTdata_100262.json (开始时间: 2025-12-21 15:05:27.053336)
#   -> 文件结束。耗时：0:00:10.239927。本文件产出样本数：11
# [14/433] 正在处理文件：POINTdata_78000.json (开始时间: 2025-12-21 15:05:37.293333)
#   -> 文件结束。耗时：0:00:09.654452。本文件产出样本数：11
# [15/433] 正在处理文件：POINTdata_137687.json (开始时间: 2025-12-21 15:05:46.947864)
#   -> 文件结束。耗时：0:00:09.827556。本文件产出样本数：11
# [16/433] 正在处理文件：POINTdata_79884.json (开始时间: 2025-12-21 15:05:56.775484)
#   -> 文件结束。耗时：0:00:09.967434。本文件产出样本数：11
# [17/433] 正在处理文件：POINTdata_106637.json (开始时间: 2025-12-21 15:06:06.742987)
#   -> 文件结束。耗时：0:00:14.500199。本文件产出样本数：11
# [18/433] 正在处理文件：POINTdata_137756.json (开始时间: 2025-12-21 15:06:21.243254)
#   -> 文件结束。耗时：0:00:11.439119。本文件产出样本数：11
# [19/433] 正在处理文件：POINTdata_79810.json (开始时间: 2025-12-21 15:06:32.682446)
#   -> 文件结束。耗时：0:00:10.040592。本文件产出样本数：11
# [20/433] 正在处理文件：POINTdata_106725.json (开始时间: 2025-12-21 15:06:42.723109)
#   -> 文件结束。耗时：0:00:13.456791。本文件产出样本数：11
# [21/433] 正在处理文件：POINTdata_80218.json (开始时间: 2025-12-21 15:06:56.179965)
#   -> 文件结束。耗时：0:00:09.884717。本文件产出样本数：11
# [22/433] 正在处理文件：POINTdata_146838.json (开始时间: 2025-12-21 15:07:06.064742)
#   -> 文件结束。耗时：0:00:15.446377。本文件产出样本数：11
# [23/433] 正在处理文件：POINTdata_58863.json (开始时间: 2025-12-21 15:07:21.511189)
#   -> 文件结束。耗时：0:00:09.789681。本文件产出样本数：11
# [24/433] 正在处理文件：POINTdata_137644.json (开始时间: 2025-12-21 15:07:31.300933)
#   -> 文件结束。耗时：0:00:11.488653。本文件产出样本数：11
# [25/433] 正在处理文件：POINTdata_80131.json (开始时间: 2025-12-21 15:07:42.789657)
#   -> 文件结束。耗时：0:00:09.702195。本文件产出样本数：11
# [26/433] 正在处理文件：POINTdata_100022.json (开始时间: 2025-12-21 15:07:52.491921)
#   -> 文件结束。耗时：0:00:10.174058。本文件产出样本数：11
# [27/433] 正在处理文件：POINTdata_100188.json (开始时间: 2025-12-21 15:08:02.666065)
#   -> 文件结束。耗时：0:00:12.474566。本文件产出样本数：11
# [28/433] 正在处理文件：POINTdata_100171.json (开始时间: 2025-12-21 15:08:15.140697)
#   -> 文件结束。耗时：0:00:10.115159。本文件产出样本数：11
# [29/433] 正在处理文件：POINTdata_100034.json (开始时间: 2025-12-21 15:08:25.255921)
#   -> 文件结束。耗时：0:00:10.105149。本文件产出样本数：11
# [30/433] 正在处理文件：POINTdata_106334.json (开始时间: 2025-12-21 15:08:35.361146)
#   -> 文件结束。耗时：0:00:11.157080。本文件产出样本数：11
# [31/433] 正在处理文件：POINTdata_137469.json (开始时间: 2025-12-21 15:08:46.518312)
#   -> 文件结束。耗时：0:00:11.621247。本文件产出样本数：11
# [32/433] 正在处理文件：POINTdata_99994.json (开始时间: 2025-12-21 15:08:58.139652)
#   -> 文件结束。耗时：0:00:10.122758。本文件产出样本数：11
# [33/433] 正在处理文件：POINTdata_137740.json (开始时间: 2025-12-21 15:09:08.262498)
#   -> 文件结束。耗时：0:00:11.548491。本文件产出样本数：11
# [34/433] 正在处理文件：POINTdata_137737.json (开始时间: 2025-12-21 15:09:19.811078)
#   -> 文件结束。耗时：0:00:11.455727。本文件产出样本数：11
# [35/433] 正在处理文件：POINTdata_79871.json (开始时间: 2025-12-21 15:09:31.266869)
#   -> 文件结束。耗时：0:00:09.785640。本文件产出样本数：11
# [36/433] 正在处理文件：POINTdata_100014.json (开始时间: 2025-12-21 15:09:41.052571)
#   -> 文件结束。耗时：0:00:10.141316。本文件产出样本数：11
# [37/433] 正在处理文件：POINTdata_137672.json (开始时间: 2025-12-21 15:09:51.193953)
#   -> 文件结束。耗时：0:00:09.902042。本文件产出样本数：11
# [38/433] 正在处理文件：POINTdata_106343.json (开始时间: 2025-12-21 15:10:01.096064)
#   -> 文件结束。耗时：0:00:14.620877。本文件产出样本数：11
# [39/433] 正在处理文件：POINTdata_79826.json (开始时间: 2025-12-21 15:10:15.717037)
#   -> 文件结束。耗时：0:00:09.908933。本文件产出样本数：11
# [40/433] 正在处理文件：POINTdata_106894.json (开始时间: 2025-12-21 15:10:25.626036)
#   -> 文件结束。耗时：0:00:11.167265。本文件产出样本数：11
# [41/433] 正在处理文件：POINTdata_106744.json (开始时间: 2025-12-21 15:10:36.793362)
#   -> 文件结束。耗时：0:00:14.396914。本文件产出样本数：11
# [42/433] 正在处理文件：POINTdata_137776.json (开始时间: 2025-12-21 15:10:51.190342)
#   -> 文件结束。耗时：0:00:11.592539。本文件产出样本数：11
# [43/433] 正在处理文件：POINTdata_106882.json (开始时间: 2025-12-21 15:11:02.782951)
#   -> 文件结束。耗时：0:00:14.462382。本文件产出样本数：11
# [44/433] 正在处理文件：POINTdata_79830.json (开始时间: 2025-12-21 15:11:17.245436)
#   -> 文件结束。耗时：0:00:09.825362。本文件产出样本数：11
# [45/433] 正在处理文件：POINTdata_106494.json (开始时间: 2025-12-21 15:11:27.070897)
#   -> 文件结束。耗时：0:00:13.574943。本文件产出样本数：11
# [46/433] 正在处理文件：POINTdata_106617.json (开始时间: 2025-12-21 15:11:40.645924)
#   -> 文件结束。耗时：0:00:13.551783。本文件产出样本数：11
# [47/433] 正在处理文件：POINTdata_106752.json (开始时间: 2025-12-21 15:11:54.197771)
#   -> 文件结束。耗时：0:00:14.578080。本文件产出样本数：11
# [48/433] 正在处理文件：POINTdata_106302.json (开始时间: 2025-12-21 15:12:08.775913)
#   -> 文件结束。耗时：0:00:11.131985。本文件产出样本数：11
# [49/433] 正在处理文件：POINTdata_100002.json (开始时间: 2025-12-21 15:12:19.907965)
#   -> 文件结束。耗时：0:00:10.357460。本文件产出样本数：11
# [50/433] 正在处理文件：POINTdata_137664.json (开始时间: 2025-12-21 15:12:30.265487)
#   -> 文件结束。耗时：0:00:09.898797。本文件产出样本数：11
# [51/433] 正在处理文件：POINTdata_137473.json (开始时间: 2025-12-21 15:12:40.164353)
#   -> 文件结束。耗时：0:00:11.681502。本文件产出样本数：11
# [52/433] 正在处理文件：POINTdata_137648.json (开始时间: 2025-12-21 15:12:51.845923)
#   -> 文件结束。耗时：0:00:11.519152。本文件产出样本数：11
# [53/433] 正在处理文件：POINTdata_100184.json (开始时间: 2025-12-21 15:13:03.365143)
#   -> 文件结束。耗时：0:00:12.244159。本文件产出样本数：11
# [54/433] 正在处理文件：POINTdata_137561.json (开始时间: 2025-12-21 15:13:15.609364)
#   -> 文件结束。耗时：0:00:11.479012。本文件产出样本数：11
# [55/433] 正在处理文件：POINTdata_77005.json (开始时间: 2025-12-21 15:13:27.088440)
#   -> 文件结束。耗时：0:00:09.861612。本文件产出样本数：11
# [56/433] 正在处理文件：POINTdata_100192.json (开始时间: 2025-12-21 15:13:36.950118)
#   -> 文件结束。耗时：0:00:12.249090。本文件产出样本数：11
# [57/433] 正在处理文件：POINTdata_146822.json (开始时间: 2025-12-21 15:13:49.199274)
#   -> 文件结束。耗时：0:00:15.497892。本文件产出样本数：11
# [58/433] 正在处理文件：POINTdata_77951.json (开始时间: 2025-12-21 15:14:04.697236)
#   -> 文件结束。耗时：0:00:09.887601。本文件产出样本数：11
# [59/433] 正在处理文件：POINTdata_99977.json (开始时间: 2025-12-21 15:14:14.584913)
#   -> 文件结束。耗时：0:00:09.980745。本文件产出样本数：11
# [60/433] 正在处理文件：POINTdata_100203.json (开始时间: 2025-12-21 15:14:24.565782)
#   -> 文件结束。耗时：0:00:10.248478。本文件产出样本数：11
# [61/433] 正在处理文件：POINTdata_99998.json (开始时间: 2025-12-21 15:14:34.814331)
#   -> 文件结束。耗时：0:00:10.138921。本文件产出样本数：11
# [62/433] 正在处理文件：POINTdata_99976.json (开始时间: 2025-12-21 15:14:44.953318)
#   -> 文件结束。耗时：0:00:10.139101。本文件产出样本数：11
# [63/433] 正在处理文件：POINTdata_106769.json (开始时间: 2025-12-21 15:14:55.092480)
#   -> 文件结束。耗时：0:00:14.405202。本文件产出样本数：11
# [64/433] 正在处理文件：POINTdata_106339.json (开始时间: 2025-12-21 15:15:09.497746)
#   -> 文件结束。耗时：0:00:11.161959。本文件产出样本数：11
# [65/433] 正在处理文件：POINTdata_100202.json (开始时间: 2025-12-21 15:15:20.659770)
#   -> 文件结束。耗时：0:00:10.199601。本文件产出样本数：11
# [66/433] 正在处理文件：POINTdata_99999.json (开始时间: 2025-12-21 15:15:30.859446)
#   -> 文件结束。耗时：0:00:10.107825。本文件产出样本数：11
# [67/433] 正在处理文件：POINTdata_77950.json (开始时间: 2025-12-21 15:15:40.967336)
#   -> 文件结束。耗时：0:00:09.864588。本文件产出样本数：11
# [68/433] 正在处理文件：POINTdata_80203.json (开始时间: 2025-12-21 15:15:50.832021)
#   -> 文件结束。耗时：0:00:09.749620。本文件产出样本数：11
# [69/433] 正在处理文件：POINTdata_137576.json (开始时间: 2025-12-21 15:16:00.581710)
#   -> 文件结束。耗时：0:00:11.401419。本文件产出样本数：11
# [70/433] 正在处理文件：POINTdata_100193.json (开始时间: 2025-12-21 15:16:11.983195)
#   -> 文件结束。耗时：0:00:07.982163。本文件产出样本数：11
# [71/433] 正在处理文件：POINTdata_146835.json (开始时间: 2025-12-21 15:16:19.965423)
#   -> 文件结束。耗时：0:00:15.223052。本文件产出样本数：11
# [72/433] 正在处理文件：POINTdata_106728.json (开始时间: 2025-12-21 15:16:35.188539)
#   -> 文件结束。耗时：0:00:13.231508。本文件产出样本数：11
# [73/433] 正在处理文件：POINTdata_58881.json (开始时间: 2025-12-21 15:16:48.420116)
#   -> 文件结束。耗时：0:00:09.893112。本文件产出样本数：11
# [74/433] 正在处理文件：POINTdata_137560.json (开始时间: 2025-12-21 15:16:58.313294)
#   -> 文件结束。耗时：0:00:11.448682。本文件产出样本数：11
# [75/433] 正在处理文件：POINTdata_100185.json (开始时间: 2025-12-21 15:17:09.762041)
#   -> 文件结束。耗时：0:00:12.195060。本文件产出样本数：11
# [76/433] 正在处理文件：POINTdata_77946.json (开始时间: 2025-12-21 15:17:21.957169)
#   -> 文件结束。耗时：0:00:09.831447。本文件产出样本数：11
# [77/433] 正在处理文件：POINTdata_106905.json (开始时间: 2025-12-21 15:17:31.788682)
#   -> 文件结束。耗时：0:00:15.183026。本文件产出样本数：11
# [78/433] 正在处理文件：POINTdata_146819.json (开始时间: 2025-12-21 15:17:46.971775)
#   -> 文件结束。耗时：0:00:15.164634。本文件产出样本数：11
# [79/433] 正在处理文件：POINTdata_100003.json (开始时间: 2025-12-21 15:18:02.136474)
#   -> 文件结束。耗时：0:00:10.175775。本文件产出样本数：11
# [80/433] 正在处理文件：POINTdata_137665.json (开始时间: 2025-12-21 15:18:12.312314)
#   -> 文件结束。耗时：0:00:09.910739。本文件产出样本数：11
# [81/433] 正在处理文件：POINTdata_106753.json (开始时间: 2025-12-21 15:18:22.223122)
#   -> 文件结束。耗时：0:00:14.495021。本文件产出样本数：11
# [82/433] 正在处理文件：POINTdata_137777.json (开始时间: 2025-12-21 15:18:36.718226)
#   -> 文件结束。耗时：0:00:11.450934。本文件产出样本数：11
# [83/433] 正在处理文件：POINTdata_106315.json (开始时间: 2025-12-21 15:18:48.169231)
#   -> 文件结束。耗时：0:00:11.254726。本文件产出样本数：11
# [84/433] 正在处理文件：POINTdata_106745.json (开始时间: 2025-12-21 15:18:59.424026)
#   -> 文件结束。耗时：0:00:14.581059。本文件产出样本数：11
# [85/433] 正在处理文件：POINTdata_79827.json (开始时间: 2025-12-21 15:19:14.005354)
#   -> 文件结束。耗时：0:00:09.860565。本文件产出样本数：11
# [86/433] 正在处理文件：POINTdata_137761.json (开始时间: 2025-12-21 15:19:23.865987)
#   -> 文件结束。耗时：0:00:11.363068。本文件产出样本数：11
# [87/433] 正在处理文件：POINTdata_137736.json (开始时间: 2025-12-21 15:19:35.229168)
#   -> 文件结束。耗时：0:00:11.498204。本文件产出样本数：11
# [88/433] 正在处理文件：POINTdata_100015.json (开始时间: 2025-12-21 15:19:46.727438)
#   -> 文件结束。耗时：0:00:10.051779。本文件产出样本数：11
# [89/433] 正在处理文件：POINTdata_80043.json (开始时间: 2025-12-21 15:19:56.779281)
#   -> 文件结束。耗时：0:00:09.802097。本文件产出样本数：11
# [90/433] 正在处理文件：POINTdata_137673.json (开始时间: 2025-12-21 15:20:06.581443)
#   -> 文件结束。耗时：0:00:09.771995。本文件产出样本数：11
# [91/433] 正在处理文件：POINTdata_79807.json (开始时间: 2025-12-21 15:20:16.353502)
#   -> 文件结束。耗时：0:00:09.935802。本文件产出样本数：11
# [92/433] 正在处理文件：POINTdata_137741.json (开始时间: 2025-12-21 15:20:26.289384)
#   -> 文件结束。耗时：0:00:11.383887。本文件产出样本数：11
# [93/433] 正在处理文件：POINTdata_106335.json (开始时间: 2025-12-21 15:20:37.673336)
#   -> 文件结束。耗时：0:00:11.118383。本文件产出样本数：11
# [94/433] 正在处理文件：POINTdata_100170.json (开始时间: 2025-12-21 15:20:48.791799)
#   -> 文件结束。耗时：0:00:10.131811。本文件产出样本数：11
# [95/433] 正在处理文件：POINTdata_100035.json (开始时间: 2025-12-21 15:20:58.923673)
#   -> 文件结束。耗时：0:00:10.101614。本文件产出样本数：11
# [96/433] 正在处理文件：POINTdata_100023.json (开始时间: 2025-12-21 15:21:09.025355)
#   -> 文件结束。耗时：0:00:10.236145。本文件产出样本数：11
# [97/433] 正在处理文件：POINTdata_100189.json (开始时间: 2025-12-21 15:21:19.261562)
#   -> 文件结束。耗时：0:00:12.481562。本文件产出样本数：11
# [98/433] 正在处理文件：POINTdata_137700.json (开始时间: 2025-12-21 15:21:31.743192)
#   -> 文件结束。耗时：0:00:10.022658。本文件产出样本数：11
# [99/433] 正在处理文件：POINTdata_80219.json (开始时间: 2025-12-21 15:21:41.765924)
#   -> 文件结束。耗时：0:00:10.015032。本文件产出样本数：11
# [100/433] 正在处理文件：POINTdata_137583.json (开始时间: 2025-12-21 15:21:51.781071)
#   -> 文件结束。耗时：0:00:11.629751。本文件产出样本数：11
# [101/433] 正在处理文件：POINTdata_80188.json (开始时间: 2025-12-21 15:22:03.410890)
#   -> 文件结束。耗时：0:00:09.791564。本文件产出样本数：11
# [102/433] 正在处理文件：POINTdata_137757.json (开始时间: 2025-12-21 15:22:13.202518)
#   -> 文件结束。耗时：0:00:11.596064。本文件产出样本数：11
# [103/433] 正在处理文件：POINTdata_106909.json (开始时间: 2025-12-21 15:22:24.798654)
#   -> 文件结束。耗时：0:00:11.268334。本文件产出样本数：11
# [104/433] 正在处理文件：POINTdata_79811.json (开始时间: 2025-12-21 15:22:36.067054)
#   -> 文件结束。耗时：0:00:10.165533。本文件产出样本数：11
# [105/433] 正在处理文件：POINTdata_106773.json (开始时间: 2025-12-21 15:22:46.232650)
#   -> 文件结束。耗时：0:00:15.835564。本文件产出样本数：11
# [106/433] 正在处理文件：POINTdata_106323.json (开始时间: 2025-12-21 15:23:02.068282)
#   -> 文件结束。耗时：0:00:11.271543。本文件产出样本数：11
# [107/433] 正在处理文件：POINTdata_99983.json (开始时间: 2025-12-21 15:23:13.339891)
#   -> 文件结束。耗时：0:00:10.359861。本文件产出样本数：11
# [108/433] 正在处理文件：POINTdata_137686.json (开始时间: 2025-12-21 15:23:23.699815)
#   -> 文件结束。耗时：0:00:10.258688。本文件产出样本数：11
# [109/433] 正在处理文件：POINTdata_77874.json (开始时间: 2025-12-21 15:23:33.958578)
#   -> 文件结束。耗时：0:00:11.012379。本文件产出样本数：11
# [110/433] 正在处理文件：POINTdata_137669.json (开始时间: 2025-12-21 15:23:44.971077)
#   -> 文件结束。耗时：0:00:11.298970。本文件产出样本数：11
# [111/433] 正在处理文件：POINTdata_100263.json (开始时间: 2025-12-21 15:23:56.270115)
#   -> 文件结束。耗时：0:00:11.139473。本文件产出样本数：11
# [112/433] 正在处理文件：POINTdata_106476.json (开始时间: 2025-12-21 15:24:07.409648)
#   -> 文件结束。耗时：0:00:14.802305。本文件产出样本数：11
# [113/433] 正在处理文件：POINTdata_146907.json (开始时间: 2025-12-21 15:24:22.212026)
#   -> 文件结束。耗时：0:00:16.300336。本文件产出样本数：11
# [114/433] 正在处理文件：POINTdata_77970.json (开始时间: 2025-12-21 15:24:38.512436)
#   -> 文件结束。耗时：0:00:10.352182。本文件产出样本数：11
# [115/433] 正在处理文件：POINTdata_106876.json (开始时间: 2025-12-21 15:24:48.864683)
#   -> 文件结束。耗时：0:00:13.518776。本文件产出样本数：11
# [116/433] 正在处理文件：POINTdata_106749.json (开始时间: 2025-12-21 15:25:02.383532)
#   -> 文件结束。耗时：0:00:15.151970。本文件产出样本数：11
# [117/433] 正在处理文件：POINTdata_106319.json (开始时间: 2025-12-21 15:25:17.535585)
#   -> 文件结束。耗时：0:00:11.513024。本文件产出样本数：11
# [118/433] 正在处理文件：POINTdata_100019.json (开始时间: 2025-12-21 15:25:29.048675)
#   -> 文件结束。耗时：0:00:10.500206。本文件产出样本数：11
# [119/433] 正在处理文件：POINTdata_137556.json (开始时间: 2025-12-21 15:25:39.548947)
#   -> 文件结束。耗时：0:00:11.770004。本文件产出样本数：11
# [120/433] 正在处理文件：POINTdata_78017.json (开始时间: 2025-12-21 15:25:51.319013)
#   -> 文件结束。耗时：0:00:10.302473。本文件产出样本数：11
# [121/433] 正在处理文件：POINTdata_100012.json (开始时间: 2025-12-21 15:26:01.621550)
#   -> 文件结束。耗时：0:00:10.546528。本文件产出样本数：11
# [122/433] 正在处理文件：POINTdata_137674.json (开始时间: 2025-12-21 15:26:12.168142)
#   -> 文件结束。耗时：0:00:10.425258。本文件产出样本数：11
# [123/433] 正在处理文件：POINTdata_58853.json (开始时间: 2025-12-21 15:26:22.593469)
#   -> 文件结束。耗时：0:00:10.298179。本文件产出样本数：11
# [124/433] 正在处理文件：POINTdata_79820.json (开始时间: 2025-12-21 15:26:32.891746)
#   -> 文件结束。耗时：0:00:10.233236。本文件产出样本数：11
# [125/433] 正在处理文件：POINTdata_137766.json (开始时间: 2025-12-21 15:26:43.125053)
#   -> 文件结束。耗时：0:00:09.302493。本文件产出样本数：11
# [126/433] 正在处理文件：POINTdata_106312.json (开始时间: 2025-12-21 15:26:52.427658)
#   -> 文件结束。耗时：0:00:11.585614。本文件产出样本数：11
# [127/433] 正在处理文件：POINTdata_106492.json (开始时间: 2025-12-21 15:27:04.013353)
#   -> 文件结束。耗时：0:00:14.360395。本文件产出样本数：11
# [128/433] 正在处理文件：POINTdata_106754.json (开始时间: 2025-12-21 15:27:18.373821)
#   -> 文件结束。耗时：0:00:14.997881。本文件产出样本数：11
# [129/433] 正在处理文件：POINTdata_100004.json (开始时间: 2025-12-21 15:27:33.371769)
#   -> 文件结束。耗时：0:00:10.415598。本文件产出样本数：11
# [130/433] 正在处理文件：POINTdata_80117.json (开始时间: 2025-12-21 15:27:43.787438)
#   -> 文件结束。耗时：0:00:05.928648。本文件产出样本数：11
# [131/433] 正在处理文件：POINTdata_137662.json (开始时间: 2025-12-21 15:27:49.716155)
#   -> 文件结束。耗时：0:00:10.547030。本文件产出样本数：11
# [132/433] 正在处理文件：POINTdata_100268.json (开始时间: 2025-12-21 15:28:00.263248)
#   -> 文件结束。耗时：0:00:10.751511。本文件产出样本数：11
# [133/433] 正在处理文件：POINTdata_80029.json (开始时间: 2025-12-21 15:28:11.014818)
#   -> 文件结束。耗时：0:00:10.116814。本文件产出样本数：11
# [134/433] 正在处理文件：POINTdata_137475.json (开始时间: 2025-12-21 15:28:21.131699)
#   -> 文件结束。耗时：0:00:10.879727。本文件产出样本数：11
# [135/433] 正在处理文件：POINTdata_80245.json (开始时间: 2025-12-21 15:28:32.011489)
#   -> 文件结束。耗时：0:00:09.952071。本文件产出样本数：11
# [136/433] 正在处理文件：POINTdata_99988.json (开始时间: 2025-12-21 15:28:41.963627)
#   -> 文件结束。耗时：0:00:10.196385。本文件产出样本数：11
# [137/433] 正在处理文件：POINTdata_77015.json (开始时间: 2025-12-21 15:28:52.160078)
#   -> 文件结束。耗时：0:00:09.831914。本文件产出样本数：11
# [138/433] 正在处理文件：POINTdata_100182.json (开始时间: 2025-12-21 15:29:01.992051)
#   -> 文件结束。耗时：0:00:12.691935。本文件产出样本数：11
# [139/433] 正在处理文件：POINTdata_100028.json (开始时间: 2025-12-21 15:29:14.684048)
#   -> 文件结束。耗时：0:00:10.708368。本文件产出样本数：11
# [140/433] 正在处理文件：POINTdata_137588.json (开始时间: 2025-12-21 15:29:25.392478)
#   -> 文件结束。耗时：0:00:12.219942。本文件产出样本数：11
# [141/433] 正在处理文件：POINTdata_58869.json (开始时间: 2025-12-21 15:29:37.612493)
#   -> 文件结束。耗时：0:00:10.679770。本文件产出样本数：11
# [142/433] 正在处理文件：POINTdata_106390.json (开始时间: 2025-12-21 15:29:48.292490)
#   -> 文件结束。耗时：0:00:14.214416。本文件产出样本数：11
# [143/433] 正在处理文件：POINTdata_77003.json (开始时间: 2025-12-21 15:30:02.507007)
#   -> 文件结束。耗时：0:00:10.098404。本文件产出样本数：11
# [144/433] 正在处理文件：POINTdata_137658.json (开始时间: 2025-12-21 15:30:12.605554)
#   -> 文件结束。耗时：0:00:13.067906。本文件产出样本数：11
# [145/433] 正在处理文件：POINTdata_106386.json (开始时间: 2025-12-21 15:30:25.673599)
#   -> 文件结束。耗时：0:00:18.518350。本文件产出样本数：11
# [146/433] 正在处理文件：POINTdata_137571.json (开始时间: 2025-12-21 15:30:44.192163)
#   -> 文件结束。耗时：0:00:16.242815。本文件产出样本数：11
# [147/433] 正在处理文件：POINTdata_58890.json (开始时间: 2025-12-21 15:31:00.435382)
#   -> 文件结束。耗时：0:00:14.229991。本文件产出样本数：11
# [148/433] 正在处理文件：POINTdata_137551.json (开始时间: 2025-12-21 15:31:14.665584)
#   -> 文件结束。耗时：0:00:16.639194。本文件产出样本数：11
# [149/433] 正在处理文件：POINTdata_79251.json (开始时间: 2025-12-21 15:31:31.304875)
#   -> 文件结束。耗时：0:00:13.887499。本文件产出样本数：11
# [150/433] 正在处理文件：POINTdata_77998.json (开始时间: 2025-12-21 15:31:45.192757)
#   -> 文件结束。耗时：0:00:13.880123。本文件产出样本数：11
# [151/433] 正在处理文件：POINTdata_106467.json (开始时间: 2025-12-21 15:31:59.072996)
#   -> 文件结束。耗时：0:00:15.957233。本文件产出样本数：11
# [152/433] 正在处理文件：POINTdata_106488.json (开始时间: 2025-12-21 15:32:15.030309)
#   -> 文件结束。耗时：0:00:18.973348。本文件产出样本数：11
# [153/433] 正在处理文件：POINTdata_146845.json (开始时间: 2025-12-21 15:32:34.003737)
#   -> 文件结束。耗时：0:00:21.684574。本文件产出样本数：11
# [154/433] 正在处理文件：POINTdata_106308.json (开始时间: 2025-12-21 15:32:55.688390)
#   -> 文件结束。耗时：0:00:15.945936。本文件产出样本数：11
# [155/433] 正在处理文件：POINTdata_106758.json (开始时间: 2025-12-21 15:33:11.634462)
#   -> 文件结束。耗时：0:00:20.713228。本文件产出样本数：11
# [156/433] 正在处理文件：POINTdata_106471.json (开始时间: 2025-12-21 15:33:32.347773)
#   -> 文件结束。耗时：0:00:19.081384。本文件产出样本数：11
# [157/433] 正在处理文件：POINTdata_79569.json (开始时间: 2025-12-21 15:33:51.429255)
#   -> 文件结束。耗时：0:00:13.577244。本文件产出样本数：11
# [158/433] 正在处理文件：POINTdata_100264.json (开始时间: 2025-12-21 15:34:05.006581)
#   -> 文件结束。耗时：0:00:14.416664。本文件产出样本数：11
# [159/433] 正在处理文件：POINTdata_137547.json (开始时间: 2025-12-21 15:34:19.423345)
#   -> 文件结束。耗时：0:00:16.123959。本文件产出样本数：11
# [160/433] 正在处理文件：POINTdata_79247.json (开始时间: 2025-12-21 15:34:35.547392)
#   -> 文件结束。耗时：0:00:13.560403。本文件产出样本数：11
# [161/433] 正在处理文件：POINTdata_77873.json (开始时间: 2025-12-21 15:34:49.107866)
#   -> 文件结束。耗时：0:00:13.535254。本文件产出样本数：11
# [162/433] 正在处理文件：POINTdata_100008.json (开始时间: 2025-12-21 15:35:02.643209)
#   -> 文件结束。耗时：0:00:13.827221。本文件产出样本数：11
# [163/433] 正在处理文件：POINTdata_79882.json (开始时间: 2025-12-21 15:35:16.470545)
#   -> 文件结束。耗时：0:00:13.619562。本文件产出样本数：11
# [164/433] 正在处理文件：POINTdata_137479.json (开始时间: 2025-12-21 15:35:30.090186)
#   -> 文件结束。耗时：0:00:18.785185。本文件产出样本数：11
# [165/433] 正在处理文件：POINTdata_99984.json (开始时间: 2025-12-21 15:35:48.875739)
#   -> 文件结束。耗时：0:00:15.105241。本文件产出样本数：11
# [166/433] 正在处理文件：POINTdata_106631.json (开始时间: 2025-12-21 15:36:03.981326)
#   -> 文件结束。耗时：0:00:21.849345。本文件产出样本数：11
# [167/433] 正在处理文件：POINTdata_137750.json (开始时间: 2025-12-21 15:36:25.830814)
#   -> 文件结束。耗时：0:00:16.863718。本文件产出样本数：11
# [168/433] 正在处理文件：POINTdata_58865.json (开始时间: 2025-12-21 15:36:42.694874)
#   -> 文件结束。耗时：0:00:14.347282。本文件产出样本数：11
# [169/433] 正在处理文件：POINTdata_100024.json (开始时间: 2025-12-21 15:36:57.042241)
#   -> 文件结束。耗时：0:00:15.047122。本文件产出样本数：11
# [170/433] 正在处理文件：POINTdata_106735.json (开始时间: 2025-12-21 15:37:12.089448)
#   -> 文件结束。耗时：0:00:19.887602。本文件产出样本数：11
# [171/433] 正在处理文件：POINTdata_100177.json (开始时间: 2025-12-21 15:37:31.977225)
#   -> 文件结束。耗时：0:00:15.173105。本文件产出样本数：11
# [172/433] 正在处理文件：POINTdata_80121.json (开始时间: 2025-12-21 15:37:47.150438)
#   -> 文件结束。耗时：0:00:18.190885。本文件产出样本数：11
# [173/433] 正在处理文件：POINTdata_100198.json (开始时间: 2025-12-21 15:38:05.341666)
#   -> 文件结束。耗时：0:00:14.747740。本文件产出样本数：11
# [174/433] 正在处理文件：POINTdata_99992.json (开始时间: 2025-12-21 15:38:20.089493)
#   -> 文件结束。耗时：0:00:15.232983。本文件产出样本数：11
# [175/433] 正在处理文件：POINTdata_137480.json (开始时间: 2025-12-21 15:38:35.322577)
#   -> 文件结束。耗时：0:00:17.102170。本文件产出样本数：11
# [176/433] 正在处理文件：POINTdata_80199.json (开始时间: 2025-12-21 15:38:52.424841)
#   -> 文件结束。耗时：0:00:14.849947。本文件产出样本数：11
# [177/433] 正在处理文件：POINTdata_137746.json (开始时间: 2025-12-21 15:39:07.274938)
#   -> 文件结束。耗时：0:00:17.053045。本文件产出样本数：11
# [178/433] 正在处理文件：POINTdata_137747.json (开始时间: 2025-12-21 15:39:24.328094)
#   -> 文件结束。耗时：0:00:17.593492。本文件产出样本数：11
# [179/433] 正在处理文件：POINTdata_106763.json (开始时间: 2025-12-21 15:39:41.921665)
#   -> 文件结束。耗时：0:00:22.654059。本文件产出样本数：11
# [180/433] 正在处理文件：POINTdata_99993.json (开始时间: 2025-12-21 15:40:04.575815)
#   -> 文件结束。耗时：0:00:14.874502。本文件产出样本数：11
# [181/433] 正在处理文件：POINTdata_137655.json (开始时间: 2025-12-21 15:40:19.450479)
#   -> 文件结束。耗时：0:00:16.918034。本文件产出样本数：11
# [182/433] 正在处理文件：POINTdata_100176.json (开始时间: 2025-12-21 15:40:36.368604)
#   -> 文件结束。耗时：0:00:14.836333。本文件产出样本数：11
# [183/433] 正在处理文件：POINTdata_106734.json (开始时间: 2025-12-21 15:40:51.205076)
#   -> 文件结束。耗时：0:00:19.918340。本文件产出样本数：11
# [184/433] 正在处理文件：POINTdata_100025.json (开始时间: 2025-12-21 15:41:11.123566)
#   -> 文件结束。耗时：0:00:14.998110。本文件产出样本数：11
# [185/433] 正在处理文件：POINTdata_58864.json (开始时间: 2025-12-21 15:41:26.121773)
#   -> 文件结束。耗时：0:00:14.784101。本文件产出样本数：11
# [186/433] 正在处理文件：POINTdata_137585.json (开始时间: 2025-12-21 15:41:40.905995)
#   -> 文件结束。耗时：0:00:16.939920。本文件产出样本数：11
# [187/433] 正在处理文件：POINTdata_137751.json (开始时间: 2025-12-21 15:41:57.846242)
#   -> 文件结束。耗时：0:00:16.882772。本文件产出样本数：11
# [188/433] 正在处理文件：POINTdata_137478.json (开始时间: 2025-12-21 15:42:14.729097)
#   -> 文件结束。耗时：0:00:16.771333。本文件产出样本数：11
# [189/433] 正在处理文件：POINTdata_77366.json (开始时间: 2025-12-21 15:42:31.500524)
#   -> 文件结束。耗时：0:00:14.108921。本文件产出样本数：11
# [190/433] 正在处理文件：POINTdata_99985.json (开始时间: 2025-12-21 15:42:45.609535)
#   -> 文件结束。耗时：0:00:14.847337。本文件产出样本数：11
# [191/433] 正在处理文件：POINTdata_106630.json (开始时间: 2025-12-21 15:43:00.456976)
#   -> 文件结束。耗时：0:00:13.959101。本文件产出样本数：11
# [192/433] 正在处理文件：POINTdata_77872.json (开始时间: 2025-12-21 15:43:14.416238)
#   -> 文件结束。耗时：0:00:14.089926。本文件产出样本数：11
# [193/433] 正在处理文件：POINTdata_100009.json (开始时间: 2025-12-21 15:43:28.506259)
#   -> 文件结束。耗时：0:00:14.539609。本文件产出样本数：11
# [194/433] 正在处理文件：POINTdata_79883.json (开始时间: 2025-12-21 15:43:43.045962)
#   -> 文件结束。耗时：0:00:14.225031。本文件产出样本数：11
# [195/433] 正在处理文件：POINTdata_77937.json (开始时间: 2025-12-21 15:43:57.271069)
#   -> 文件结束。耗时：0:00:14.449428。本文件产出样本数：11
# [196/433] 正在处理文件：POINTdata_100265.json (开始时间: 2025-12-21 15:44:11.720689)
#   -> 文件结束。耗时：0:00:15.136882。本文件产出样本数：11
# [197/433] 正在处理文件：POINTdata_137546.json (开始时间: 2025-12-21 15:44:26.857654)
#   -> 文件结束。耗时：0:00:16.867619。本文件产出样本数：11
# [198/433] 正在处理文件：POINTdata_106470.json (开始时间: 2025-12-21 15:44:43.725418)
#   -> 文件结束。耗时：0:00:19.768023。本文件产出样本数：11
# [199/433] 正在处理文件：POINTdata_77960.json (开始时间: 2025-12-21 15:45:03.493526)
#   -> 文件结束。耗时：0:00:14.044765。本文件产出样本数：11
# [200/433] 正在处理文件：POINTdata_131580.json (开始时间: 2025-12-21 15:45:17.538431)
#   -> 文件结束。耗时：0:00:14.250494。本文件产出样本数：11
# [201/433] 正在处理文件：POINTdata_106309.json (开始时间: 2025-12-21 15:45:31.789008)
#   -> 文件结束。耗时：0:00:16.445318。本文件产出样本数：11
# [202/433] 正在处理文件：POINTdata_106759.json (开始时间: 2025-12-21 15:45:48.234408)
#   -> 文件结束。耗时：0:00:21.106046。本文件产出样本数：11
# [203/433] 正在处理文件：POINTdata_77999.json (开始时间: 2025-12-21 15:46:09.340544)
#   -> 文件结束。耗时：0:00:14.274542。本文件产出样本数：11
# [204/433] 正在处理文件：POINTdata_106466.json (开始时间: 2025-12-21 15:46:23.615174)
#   -> 文件结束。耗时：0:00:16.376772。本文件产出样本数：11
# [205/433] 正在处理文件：POINTdata_106489.json (开始时间: 2025-12-21 15:46:39.992118)
#   -> 文件结束。耗时：0:00:21.401296。本文件产出样本数：11
# [206/433] 正在处理文件：POINTdata_106295.json (开始时间: 2025-12-21 15:47:01.393701)
#   -> 文件结束。耗时：0:00:16.180313。本文件产出样本数：11
# [207/433] 正在处理文件：POINTdata_100204.json (开始时间: 2025-12-21 15:47:17.574098)
#   -> 文件结束。耗时：0:00:14.711025。本文件产出样本数：11
# [208/433] 正在处理文件：POINTdata_80205.json (开始时间: 2025-12-21 15:47:32.285228)
#   -> 文件结束。耗时：0:00:14.419406。本文件产出样本数：11
# [209/433] 正在处理文件：POINTdata_106738.json (开始时间: 2025-12-21 15:47:46.704814)
#   -> 文件结束。耗时：0:00:20.083798。本文件产出样本数：11
# [210/433] 正在处理文件：POINTdata_58891.json (开始时间: 2025-12-21 15:48:06.788701)
#   -> 文件结束。耗时：0:00:14.501908。本文件产出样本数：11
# [211/433] 正在处理文件：POINTdata_100253.json (开始时间: 2025-12-21 15:48:21.290751)
#   -> 文件结束。耗时：0:00:15.316406。本文件产出样本数：11
# [212/433] 正在处理文件：POINTdata_80213.json (开始时间: 2025-12-21 15:48:36.607239)
#   -> 文件结束。耗时：0:00:14.694825。本文件产出样本数：11
# [213/433] 正在处理文件：POINTdata_137589.json (开始时间: 2025-12-21 15:48:51.302467)
#   -> 文件结束。耗时：0:00:16.924928。本文件产出样本数：11
# [214/433] 正在处理文件：POINTdata_58887.json (开始时间: 2025-12-21 15:49:08.227480)
#   -> 文件结束。耗时：0:00:14.388895。本文件产出样本数：11
# [215/433] 正在处理文件：POINTdata_77014.json (开始时间: 2025-12-21 15:49:22.616463)
#   -> 文件结束。耗时：0:00:14.235437。本文件产出样本数：11
# [216/433] 正在处理文件：POINTdata_100183.json (开始时间: 2025-12-21 15:49:36.852225)
#   -> 文件结束。耗时：0:00:17.912196。本文件产出样本数：11
# [217/433] 正在处理文件：POINTdata_100029.json (开始时间: 2025-12-21 15:49:54.764520)
#   -> 文件结束。耗时：0:00:14.995843。本文件产出样本数：11
# [218/433] 正在处理文件：POINTdata_137474.json (开始时间: 2025-12-21 15:50:09.760448)
#   -> 文件结束。耗时：0:00:16.879288。本文件产出样本数：11
# [219/433] 正在处理文件：POINTdata_99989.json (开始时间: 2025-12-21 15:50:26.640137)
#   -> 文件结束。耗时：0:00:14.760768。本文件产出样本数：11
# [220/433] 正在处理文件：POINTdata_80182.json (开始时间: 2025-12-21 15:50:41.401000)
#   -> 文件结束。耗时：0:00:14.337051。本文件产出样本数：11
# [221/433] 正在处理文件：POINTdata_100269.json (开始时间: 2025-12-21 15:50:55.738150)
#   -> 文件结束。耗时：0:00:15.066946。本文件产出样本数：11
# [222/433] 正在处理文件：POINTdata_100005.json (开始时间: 2025-12-21 15:51:10.805281)
#   -> 文件结束。耗时：0:00:14.950177。本文件产出样本数：11
# [223/433] 正在处理文件：POINTdata_137663.json (开始时间: 2025-12-21 15:51:25.755540)
#   -> 文件结束。耗时：0:00:14.357882。本文件产出样本数：11
# [224/433] 正在处理文件：POINTdata_106305.json (开始时间: 2025-12-21 15:51:40.113502)
#   -> 文件结束。耗时：0:00:16.438456。本文件产出样本数：11
# [225/433] 正在处理文件：POINTdata_106885.json (开始时间: 2025-12-21 15:51:56.552061)
#   -> 文件结束。耗时：0:00:21.728566。本文件产出样本数：11
# [226/433] 正在处理文件：POINTdata_106313.json (开始时间: 2025-12-21 15:52:18.280947)
#   -> 文件结束。耗时：0:00:16.671191。本文件产出样本数：11
# [227/433] 正在处理文件：POINTdata_106893.json (开始时间: 2025-12-21 15:52:34.952236)
#   -> 文件结束。耗时：0:00:16.809118。本文件产出样本数：11
# [228/433] 正在处理文件：POINTdata_137767.json (开始时间: 2025-12-21 15:52:51.761449)
#   -> 文件结束。耗时：0:00:13.246728。本文件产出样本数：11
# [229/433] 正在处理文件：POINTdata_79572.json (开始时间: 2025-12-21 15:53:05.008258)
#   -> 文件结束。耗时：0:00:14.063634。本文件产出样本数：11
# [230/433] 正在处理文件：POINTdata_106485.json (开始时间: 2025-12-21 15:53:19.072035)
#   -> 文件结束。耗时：0:00:20.003868。本文件产出样本数：11
# [231/433] 正在处理文件：POINTdata_106344.json (开始时间: 2025-12-21 15:53:39.076026)
#   -> 文件结束。耗时：0:00:21.702671。本文件产出样本数：11
# [232/433] 正在处理文件：POINTdata_58852.json (开始时间: 2025-12-21 15:54:00.778793)
#   -> 文件结束。耗时：0:00:14.549004。本文件产出样本数：11
# [233/433] 正在处理文件：POINTdata_100013.json (开始时间: 2025-12-21 15:54:15.327878)
#   -> 文件结束。耗时：0:00:14.891271。本文件产出样本数：11
# [234/433] 正在处理文件：POINTdata_137675.json (开始时间: 2025-12-21 15:54:30.219236)
#   -> 文件结束。耗时：0:00:14.293982。本文件产出样本数：11
# [235/433] 正在处理文件：POINTdata_106629.json (开始时间: 2025-12-21 15:54:44.513357)
#   -> 文件结束。耗时：0:00:21.789315。本文件产出样本数：11
# [236/433] 正在处理文件：POINTdata_100207.json (开始时间: 2025-12-21 15:55:06.303323)
#   -> 文件结束。耗时：0:00:14.934267。本文件产出样本数：11
# [237/433] 正在处理文件：POINTdata_106296.json (开始时间: 2025-12-21 15:55:21.237727)
#   -> 文件结束。耗时：0:00:16.814985。本文件产出样本数：11
# [238/433] 正在处理文件：POINTdata_137748.json (开始时间: 2025-12-21 15:55:38.052863)
#   -> 文件结束。耗时：0:00:17.185161。本文件产出样本数：11
# [239/433] 正在处理文件：POINTdata_58892.json (开始时间: 2025-12-21 15:55:55.238400)
#   -> 文件结束。耗时：0:00:14.321216。本文件产出样本数：11
# [240/433] 正在处理文件：POINTdata_100196.json (开始时间: 2025-12-21 15:56:09.559763)
#   -> 文件结束。耗时：0:00:15.069801。本文件产出样本数：11
# [241/433] 正在处理文件：POINTdata_100179.json (开始时间: 2025-12-21 15:56:24.629813)
#   -> 文件结束。耗时：0:00:15.394243。本文件产出样本数：11
# [242/433] 正在处理文件：POINTdata_106392.json (开始时间: 2025-12-21 15:56:40.024149)
#   -> 文件结束。耗时：0:00:20.066115。本文件产出样本数：11
# [243/433] 正在处理文件：POINTdata_58884.json (开始时间: 2025-12-21 15:57:00.090348)
#   -> 文件结束。耗时：0:00:14.289005。本文件产出样本数：11
# [244/433] 正在处理文件：POINTdata_137565.json (开始时间: 2025-12-21 15:57:14.379431)
#   -> 文件结束。耗时：0:00:16.979229。本文件产出样本数：11
# [245/433] 正在处理文件：POINTdata_80139.json (开始时间: 2025-12-21 15:57:31.358735)
#   -> 文件结束。耗时：0:00:14.582419。本文件产出样本数：11
# [246/433] 正在处理文件：POINTdata_77017.json (开始时间: 2025-12-21 15:57:45.941294)
#   -> 文件结束。耗时：0:00:14.030834。本文件产出样本数：11
# [247/433] 正在处理文件：POINTdata_137477.json (开始时间: 2025-12-21 15:57:59.972255)
#   -> 文件结束。耗时：0:00:16.758187。本文件产出样本数：11
# [248/433] 正在处理文件：POINTdata_79818.json (开始时间: 2025-12-21 15:58:16.730535)
#   -> 文件结束。耗时：0:00:14.773991。本文件产出样本数：11
# [249/433] 正在处理文件：POINTdata_79249.json (开始时间: 2025-12-21 15:58:31.504604)
#   -> 文件结束。耗时：0:00:14.382182。本文件产出样本数：11
# [250/433] 正在处理文件：POINTdata_137660.json (开始时间: 2025-12-21 15:58:45.886896)
#   -> 文件结束。耗时：0:00:16.696179。本文件产出样本数：11
# [251/433] 正在处理文件：POINTdata_80115.json (开始时间: 2025-12-21 15:59:02.583262)
#   -> 文件结束。耗时：0:00:14.091598。本文件产出样本数：11
# [252/433] 正在处理文件：POINTdata_100006.json (开始时间: 2025-12-21 15:59:16.675178)
#   -> 文件结束。耗时：0:00:11.313662。本文件产出样本数：11
# [253/433] 正在处理文件：POINTdata_106490.json (开始时间: 2025-12-21 15:59:27.988907)
#   -> 文件结束。耗时：0:00:16.512902。本文件产出样本数：11
# [254/433] 正在处理文件：POINTdata_137772.json (开始时间: 2025-12-21 15:59:44.502063)
#   -> 文件结束。耗时：0:00:09.816541。本文件产出样本数：11
# [255/433] 正在处理文件：POINTdata_79567.json (开始时间: 2025-12-21 15:59:54.318821)
#   -> 文件结束。耗时：0:00:10.242612。本文件产出样本数：11
# [256/433] 正在处理文件：POINTdata_106310.json (开始时间: 2025-12-21 16:00:04.561500)
#   -> 文件结束。耗时：0:00:11.909357。本文件产出样本数：11
# [257/433] 正在处理文件：POINTdata_79571.json (开始时间: 2025-12-21 16:00:16.470928)
#   -> 文件结束。耗时：0:00:10.240775。本文件产出样本数：11
# [258/433] 正在处理文件：POINTdata_137764.json (开始时间: 2025-12-21 16:00:26.711769)
#   -> 文件结束。耗时：0:00:09.393360。本文件产出样本数：11
# [259/433] 正在处理文件：POINTdata_58851.json (开始时间: 2025-12-21 16:00:36.105219)
#   -> 文件结束。耗时：0:00:10.056520。本文件产出样本数：11
# [260/433] 正在处理文件：POINTdata_137733.json (开始时间: 2025-12-21 16:00:46.161844)
#   -> 文件结束。耗时：0:00:12.151286。本文件产出样本数：11
# [261/433] 正在处理文件：POINTdata_100010.json (开始时间: 2025-12-21 16:00:58.313190)
#   -> 文件结束。耗时：0:00:10.656374。本文件产出样本数：11
# [262/433] 正在处理文件：POINTdata_79875.json (开始时间: 2025-12-21 16:01:08.969628)
#   -> 文件结束。耗时：0:00:10.685224。本文件产出样本数：11
# [263/433] 正在处理文件：POINTdata_137744.json (开始时间: 2025-12-21 16:01:19.654918)
#   -> 文件结束。耗时：0:00:11.995831。本文件产出样本数：11
# [264/433] 正在处理文件：POINTdata_99990.json (开始时间: 2025-12-21 16:01:31.651049)
#   -> 文件结束。耗时：0:00:11.030857。本文件产出样本数：11
# [265/433] 正在处理文件：POINTdata_106760.json (开始时间: 2025-12-21 16:01:42.681986)
#   -> 文件结束。耗时：0:00:15.337301。本文件产出样本数：11
# [266/433] 正在处理文件：POINTdata_100030.json (开始时间: 2025-12-21 16:01:58.019528)
#   -> 文件结束。耗时：0:00:10.947550。本文件产出样本数：11
# [267/433] 正在处理文件：POINTdata_137656.json (开始时间: 2025-12-21 16:02:08.967144)
#   -> 文件结束。耗时：0:00:12.139284。本文件产出样本数：11
# [268/433] 正在处理文件：POINTdata_100175.json (开始时间: 2025-12-21 16:02:21.106490)
#   -> 文件结束。耗时：0:00:10.867868。本文件产出样本数：11
# [269/433] 正在处理文件：POINTdata_137590.json (开始时间: 2025-12-21 16:02:31.974427)
#   -> 文件结束。耗时：0:00:12.510462。本文件产出样本数：11
# [270/433] 正在处理文件：POINTdata_100026.json (开始时间: 2025-12-21 16:02:44.484954)
#   -> 文件结束。耗时：0:00:10.559222。本文件产出样本数：11
# [271/433] 正在处理文件：POINTdata_58888.json (开始时间: 2025-12-21 16:02:55.044239)
#   -> 文件结束。耗时：0:00:10.792775。本文件产出样本数：11
# [272/433] 正在处理文件：POINTdata_137586.json (开始时间: 2025-12-21 16:03:05.837074)
#   -> 文件结束。耗时：0:00:12.141389。本文件产出样本数：11
# [273/433] 正在处理文件：POINTdata_137752.json (开始时间: 2025-12-21 16:03:17.978545)
#   -> 文件结束。耗时：0:00:12.229816。本文件产出样本数：11
# [274/433] 正在处理文件：POINTdata_79814.json (开始时间: 2025-12-21 16:03:30.208427)
#   -> 文件结束。耗时：0:00:10.651723。本文件产出样本数：11
# [275/433] 正在处理文件：POINTdata_77365.json (开始时间: 2025-12-21 16:03:40.860215)
#   -> 文件结束。耗时：0:00:10.636872。本文件产出样本数：11
# [276/433] 正在处理文件：POINTdata_99986.json (开始时间: 2025-12-21 16:03:51.497199)
#   -> 文件结束。耗时：0:00:10.666641。本文件产出样本数：11
# [277/433] 正在处理文件：POINTdata_80119.json (开始时间: 2025-12-21 16:04:02.163905)
#   -> 文件结束。耗时：0:00:16.273683。本文件产出样本数：11
# [278/433] 正在处理文件：POINTdata_77871.json (开始时间: 2025-12-21 16:04:18.437673)
#   -> 文件结束。耗时：0:00:14.019774。本文件产出样本数：11
# [279/433] 正在处理文件：POINTdata_78004.json (开始时间: 2025-12-21 16:04:32.457557)
#   -> 文件结束。耗时：0:00:14.233046。本文件产出样本数：11
# [280/433] 正在处理文件：POINTdata_137768.json (开始时间: 2025-12-21 16:04:46.690695)
#   -> 文件结束。耗时：0:00:13.374129。本文件产出样本数：11
# [281/433] 正在处理文件：POINTdata_106465.json (开始时间: 2025-12-21 16:05:00.064970)
#   -> 文件结束。耗时：0:00:17.467540。本文件产出样本数：11
# [282/433] 正在处理文件：POINTdata_146914.json (开始时间: 2025-12-21 16:05:17.532619)
#   -> 文件结束。耗时：0:00:24.825231。本文件产出样本数：11
# [283/433] 正在处理文件：POINTdata_137553.json (开始时间: 2025-12-21 16:05:42.358253)
#   -> 文件结束。耗时：0:00:17.027598。本文件产出样本数：11
# [284/433] 正在处理文件：POINTdata_100270.json (开始时间: 2025-12-21 16:05:59.385948)
#   -> 文件结束。耗时：0:00:14.454382。本文件产出样本数：11
# [285/433] 正在处理文件：POINTdata_79252.json (开始时间: 2025-12-21 16:06:13.840396)
#   -> 文件结束。耗时：0:00:10.860138。本文件产出样本数：11
# [286/433] 正在处理文件：POINTdata_100271.json (开始时间: 2025-12-21 16:06:24.700627)
#   -> 文件结束。耗时：0:00:11.451547。本文件产出样本数：11
# [287/433] 正在处理文件：POINTdata_79878.json (开始时间: 2025-12-21 16:06:36.152272)
#   -> 文件结束。耗时：0:00:10.680373。本文件产出样本数：11
# [288/433] 正在处理文件：POINTdata_137694.json (开始时间: 2025-12-21 16:06:46.832719)
#   -> 文件结束。耗时：0:00:10.200996。本文件产出样本数：11
# [289/433] 正在处理文件：POINTdata_146915.json (开始时间: 2025-12-21 16:06:57.033782)
#   -> 文件结束。耗时：0:00:16.828205。本文件产出样本数：11
# [290/433] 正在处理文件：POINTdata_106464.json (开始时间: 2025-12-21 16:07:13.862214)
#   -> 文件结束。耗时：0:00:12.173311。本文件产出样本数：11
# [291/433] 正在处理文件：POINTdata_146846.json (开始时间: 2025-12-21 16:07:26.035597)
#   -> 文件结束。耗时：0:00:16.422943。本文件产出样本数：11
# [292/433] 正在处理文件：POINTdata_77962.json (开始时间: 2025-12-21 16:07:42.458604)
#   -> 文件结束。耗时：0:00:10.522503。本文件产出样本数：11
# [293/433] 正在处理文件：POINTdata_106472.json (开始时间: 2025-12-21 16:07:52.981170)
#   -> 文件结束。耗时：0:00:14.232851。本文件产出样本数：11
# [294/433] 正在处理文件：POINTdata_80118.json (开始时间: 2025-12-21 16:08:07.214158)
#   -> 文件结束。耗时：0:00:13.264146。本文件产出样本数：11
# [295/433] 正在处理文件：POINTdata_106632.json (开始时间: 2025-12-21 16:08:20.478412)
#   -> 文件结束。耗时：0:00:15.240425。本文件产出样本数：11
# [296/433] 正在处理文件：POINTdata_77364.json (开始时间: 2025-12-21 16:08:35.718956)
#   -> 文件结束。耗时：0:00:10.265751。本文件产出样本数：11
# [297/433] 正在处理文件：POINTdata_99987.json (开始时间: 2025-12-21 16:08:45.984775)
#   -> 文件结束。耗时：0:00:10.493689。本文件产出样本数：11
# [298/433] 正在处理文件：POINTdata_137753.json (开始时间: 2025-12-21 16:08:56.478527)
#   -> 文件结束。耗时：0:00:11.794406。本文件产出样本数：11
# [299/433] 正在处理文件：POINTdata_79815.json (开始时间: 2025-12-21 16:09:08.273001)
#   -> 文件结束。耗时：0:00:10.039977。本文件产出样本数：11
# [300/433] 正在处理文件：POINTdata_137568.json (开始时间: 2025-12-21 16:09:18.313039)
#   -> 文件结束。耗时：0:00:11.750627。本文件产出样本数：11
# [301/433] 正在处理文件：POINTdata_58889.json (开始时间: 2025-12-21 16:09:30.063728)
#   -> 文件结束。耗时：0:00:09.940477。本文件产出样本数：11
# [302/433] 正在处理文件：POINTdata_58866.json (开始时间: 2025-12-21 16:09:40.004266)
#   -> 文件结束。耗时：0:00:10.132266。本文件产出样本数：11
# [303/433] 正在处理文件：POINTdata_137587.json (开始时间: 2025-12-21 16:09:50.136595)
#   -> 文件结束。耗时：0:00:11.628038。本文件产出样本数：11
# [304/433] 正在处理文件：POINTdata_100031.json (开始时间: 2025-12-21 16:10:01.764696)
#   -> 文件结束。耗时：0:00:10.359975。本文件产出样本数：11
# [305/433] 正在处理文件：POINTdata_137657.json (开始时间: 2025-12-21 16:10:12.124737)
#   -> 文件结束。耗时：0:00:11.862515。本文件产出样本数：11
# [306/433] 正在处理文件：POINTdata_100174.json (开始时间: 2025-12-21 16:10:23.987317)
#   -> 文件结束。耗时：0:00:10.549058。本文件产出样本数：11
# [307/433] 正在处理文件：POINTdata_106624.json (开始时间: 2025-12-21 16:10:34.536442)
#   -> 文件结束。耗时：0:00:14.070563。本文件产出样本数：11
# [308/433] 正在处理文件：POINTdata_106761.json (开始时间: 2025-12-21 16:10:48.607071)
#   -> 文件结束。耗时：0:00:14.731827。本文件产出样本数：11
# [309/433] 正在处理文件：POINTdata_137745.json (开始时间: 2025-12-21 16:11:03.338970)
#   -> 文件结束。耗时：0:00:11.891670。本文件产出样本数：11
# [310/433] 正在处理文件：POINTdata_80030.json (开始时间: 2025-12-21 16:11:15.230708)
#   -> 文件结束。耗时：0:00:10.297379。本文件产出样本数：11
# [311/433] 正在处理文件：POINTdata_106487.json (开始时间: 2025-12-21 16:11:25.528150)
#   -> 文件结束。耗时：0:00:14.572623。本文件产出样本数：11
# [312/433] 正在处理文件：POINTdata_106468.json (开始时间: 2025-12-21 16:11:40.100836)
#   -> 文件结束。耗时：0:00:15.733819。本文件产出样本数：11
# [313/433] 正在处理文件：POINTdata_79570.json (开始时间: 2025-12-21 16:11:55.834959)
#   -> 文件结束。耗时：0:00:14.148447。本文件产出样本数：11
# [314/433] 正在处理文件：POINTdata_77997.json (开始时间: 2025-12-21 16:12:09.983541)
#   -> 文件结束。耗时：0:00:14.761421。本文件产出样本数：11
# [315/433] 正在处理文件：POINTdata_106311.json (开始时间: 2025-12-21 16:12:24.745074)
#   -> 文件结束。耗时：0:00:16.547819。本文件产出样本数：11
# [316/433] 正在处理文件：POINTdata_106491.json (开始时间: 2025-12-21 16:12:41.293004)
#   -> 文件结束。耗时：0:00:20.639143。本文件产出样本数：11
# [317/433] 正在处理文件：POINTdata_137773.json (开始时间: 2025-12-21 16:13:01.932481)
#   -> 文件结束。耗时：0:00:13.103137。本文件产出样本数：11
# [318/433] 正在处理文件：POINTdata_79566.json (开始时间: 2025-12-21 16:13:15.035756)
#   -> 文件结束。耗时：0:00:15.126266。本文件产出样本数：11
# [319/433] 正在处理文件：POINTdata_137661.json (开始时间: 2025-12-21 16:13:30.162132)
#   -> 文件结束。耗时：0:00:17.608339。本文件产出样本数：11
# [320/433] 正在处理文件：POINTdata_100007.json (开始时间: 2025-12-21 16:13:47.770901)
#   -> 文件结束。耗时：0:00:15.048495。本文件产出样本数：11
# [321/433] 正在处理文件：POINTdata_79248.json (开始时间: 2025-12-21 16:14:02.819539)
#   -> 文件结束。耗时：0:00:14.584513。本文件产出样本数：11
# [322/433] 正在处理文件：POINTdata_137548.json (开始时间: 2025-12-21 16:14:17.404394)
#   -> 文件结束。耗时：0:00:16.945232。本文件产出样本数：11
# [323/433] 正在处理文件：POINTdata_137476.json (开始时间: 2025-12-21 16:14:34.349726)
#   -> 文件结束。耗时：0:00:16.908034。本文件产出样本数：11
# [324/433] 正在处理文件：POINTdata_100181.json (开始时间: 2025-12-21 16:14:51.257845)
#   -> 文件结束。耗时：0:00:14.751691。本文件产出样本数：11
# [325/433] 正在处理文件：POINTdata_77016.json (开始时间: 2025-12-21 16:15:06.009694)
#   -> 文件结束。耗时：0:00:14.419313。本文件产出样本数：11
# [326/433] 正在处理文件：POINTdata_137564.json (开始时间: 2025-12-21 16:15:20.429093)
#   -> 文件结束。耗时：0:00:17.158401。本文件产出样本数：11
# [327/433] 正在处理文件：POINTdata_100197.json (开始时间: 2025-12-21 16:15:37.587600)
#   -> 文件结束。耗时：0:00:15.039044。本文件产出样本数：11
# [328/433] 正在处理文件：POINTdata_100178.json (开始时间: 2025-12-21 16:15:52.626803)
#   -> 文件结束。耗时：0:00:14.796266。本文件产出样本数：11
# [329/433] 正在处理文件：POINTdata_106385.json (开始时间: 2025-12-21 16:16:07.423154)
#   -> 文件结束。耗时：0:00:16.619856。本文件产出样本数：11
# [330/433] 正在处理文件：POINTdata_77954.json (开始时间: 2025-12-21 16:16:24.043088)
#   -> 文件结束。耗时：0:00:14.529730。本文件产出样本数：11
# [331/433] 正在处理文件：POINTdata_99972.json (开始时间: 2025-12-21 16:16:38.572965)
#   -> 文件结束。耗时：0:00:14.746139。本文件产出样本数：11
# [332/433] 正在处理文件：POINTdata_80250.json (开始时间: 2025-12-21 16:16:53.319187)
#   -> 文件结束。耗时：0:00:14.852703。本文件产出样本数：11
# [333/433] 正在处理文件：POINTdata_79804.json (开始时间: 2025-12-21 16:17:08.172009)
#   -> 文件结束。耗时：0:00:14.176563。本文件产出样本数：11
# [334/433] 正在处理文件：POINTdata_137742.json (开始时间: 2025-12-21 16:17:22.348717)
#   -> 文件结束。耗时：0:00:16.799209。本文件产出样本数：11
# [335/433] 正在处理文件：POINTdata_106623.json (开始时间: 2025-12-21 16:17:39.148090)
#   -> 文件结束。耗时：0:00:19.980956。本文件产出样本数：11
# [336/433] 正在处理文件：POINTdata_99996.json (开始时间: 2025-12-21 16:17:59.129135)
#   -> 文件结束。耗时：0:00:14.642570。本文件产出样本数：11
# [337/433] 正在处理文件：POINTdata_99979.json (开始时间: 2025-12-21 16:18:13.772045)
#   -> 文件结束。耗时：0:00:14.882971。本文件产出样本数：11
# [338/433] 正在处理文件：POINTdata_106766.json (开始时间: 2025-12-21 16:18:28.655107)
#   -> 文件结束。耗时：0:00:16.496857。本文件产出样本数：11
# [339/433] 正在处理文件：POINTdata_100036.json (开始时间: 2025-12-21 16:18:45.152066)
#   -> 文件结束。耗时：0:00:14.749518。本文件产出样本数：11
# [340/433] 正在处理文件：POINTdata_137650.json (开始时间: 2025-12-21 16:18:59.901764)
#   -> 文件结束。耗时：0:00:17.087644。本文件产出样本数：11
# [341/433] 正在处理文件：POINTdata_100173.json (开始时间: 2025-12-21 16:19:16.989536)
#   -> 文件结束。耗时：0:00:14.786711。本文件产出样本数：11
# [342/433] 正在处理文件：POINTdata_100020.json (开始时间: 2025-12-21 16:19:31.776392)
#   -> 文件结束。耗时：0:00:15.255071。本文件产出样本数：11
# [343/433] 正在处理文件：POINTdata_137580.json (开始时间: 2025-12-21 16:19:47.031550)
#   -> 文件结束。耗时：0:00:16.843968。本文件产出样本数：11
# [344/433] 正在处理文件：POINTdata_106727.json (开始时间: 2025-12-21 16:20:03.875602)
#   -> 文件结束。耗时：0:00:20.062963。本文件产出样本数：11
# [345/433] 正在处理文件：POINTdata_79812.json (开始时间: 2025-12-21 16:20:23.938947)
#   -> 文件结束。耗时：0:00:14.385114。本文件产出样本数：11
# [346/433] 正在处理文件：POINTdata_77363.json (开始时间: 2025-12-21 16:20:38.324153)
#   -> 文件结束。耗时：0:00:14.582869。本文件产出样本数：11
# [347/433] 正在处理文件：POINTdata_99980.json (开始时间: 2025-12-21 16:20:52.907217)
#   -> 文件结束。耗时：0:00:15.014345。本文件产出样本数：11
# [348/433] 正在处理文件：POINTdata_106770.json (开始时间: 2025-12-21 16:21:07.921672)
#   -> 文件结束。耗时：0:00:21.645560。本文件产出样本数：11
# [349/433] 正在处理文件：POINTdata_106320.json (开始时间: 2025-12-21 16:21:29.567569)
#   -> 文件结束。耗时：0:00:16.355372。本文件产出样本数：11
# [350/433] 正在处理文件：POINTdata_100260.json (开始时间: 2025-12-21 16:21:45.923021)
#   -> 文件结束。耗时：0:00:15.641521。本文件产出样本数：11
# [351/433] 正在处理文件：POINTdata_137543.json (开始时间: 2025-12-21 16:22:01.564641)
#   -> 文件结束。耗时：0:00:17.660003。本文件产出样本数：11
# [352/433] 正在处理文件：POINTdata_77965.json (开始时间: 2025-12-21 16:22:19.224956)
#   -> 文件结束。耗时：0:00:14.469905。本文件产出样本数：11
# [353/433] 正在处理文件：POINTdata_137778.json (开始时间: 2025-12-21 16:22:33.694956)
#   -> 文件结束。耗时：0:00:17.044951。本文件产出样本数：11
# [354/433] 正在处理文件：POINTdata_106475.json (开始时间: 2025-12-21 16:22:50.740015)
#   -> 文件结束。耗时：0:00:20.385605。本文件产出样本数：11
# [355/433] 正在处理文件：POINTdata_106619.json (开始时间: 2025-12-21 16:23:11.125949)
#   -> 文件结束。耗时：0:00:20.306187。本文件产出样本数：11
# [356/433] 正在处理文件：POINTdata_137693.json (开始时间: 2025-12-21 16:23:31.432249)
#   -> 文件结束。耗时：0:00:14.489317。本文件产出样本数：11
# [357/433] 正在处理文件：POINTdata_106967.json (开始时间: 2025-12-21 16:23:45.921650)
#   -> 文件结束。耗时：0:00:19.807057。本文件产出样本数：11
# [358/433] 正在处理文件：POINTdata_137739.json (开始时间: 2025-12-21 16:24:05.729025)
#   -> 文件结束。耗时：0:00:16.677853。本文件产出样本数：11
# [359/433] 正在处理文件：POINTdata_80220.json (开始时间: 2025-12-21 16:24:22.406974)
#   -> 文件结束。耗时：0:00:14.648469。本文件产出样本数：11
# [360/433] 正在处理文件：POINTdata_137555.json (开始时间: 2025-12-21 16:24:37.055552)
#   -> 文件结束。耗时：0:00:16.978286。本文件产出样本数：11
# [361/433] 正在处理文件：POINTdata_99975.json (开始时间: 2025-12-21 16:24:54.033974)
#   -> 文件结束。耗时：0:00:14.818396。本文件产出样本数：11
# [362/433] 正在处理文件：POINTdata_79808.json (开始时间: 2025-12-21 16:25:08.852491)
#   -> 文件结束。耗时：0:00:14.766397。本文件产出样本数：11
# [363/433] 正在处理文件：POINTdata_77953.json (开始时间: 2025-12-21 16:25:23.618966)
#   -> 文件结束。耗时：0:00:10.901715。本文件产出样本数：11
# [387/433] 正在处理文件：POINTdata_137734.json (开始时间: 2025-12-21 16:31:58.785050)
#   -> 文件结束。耗时：0:00:12.318923。本文件产出样本数：11
# [388/433] 正在处理文件：POINTdata_100017.json (开始时间: 2025-12-21 16:32:11.104038)
#   -> 文件结束。耗时：0:00:11.063286。本文件产出样本数：11
# [389/433] 正在处理文件：POINTdata_106340.json (开始时间: 2025-12-21 16:32:22.167407)
#   -> 文件结束。耗时：0:00:12.390732。本文件产出样本数：11
# [390/433] 正在处理文件：POINTdata_137558.json (开始时间: 2025-12-21 16:32:34.558248)
#   -> 文件结束。耗时：0:00:12.379544。本文件产出样本数：11
# [391/433] 正在处理文件：POINTdata_106481.json (开始时间: 2025-12-21 16:32:46.937882)
#   -> 文件结束。耗时：0:00:14.631027。本文件产出样本数：11
# [392/433] 正在处理文件：POINTdata_106878.json (开始时间: 2025-12-21 16:33:01.568976)
#   -> 文件结束。耗时：0:00:14.671859。本文件产出样本数：11
# [393/433] 正在处理文件：POINTdata_79825.json (开始时间: 2025-12-21 16:33:16.241107)
#   -> 文件结束。耗时：0:00:10.802568。本文件产出样本数：11
# [394/433] 正在处理文件：POINTdata_106317.json (开始时间: 2025-12-21 16:33:27.043743)
#   -> 文件结束。耗时：0:00:15.015629。本文件产出样本数：11
# [395/433] 正在处理文件：POINTdata_137775.json (开始时间: 2025-12-21 16:33:42.059685)
#   -> 文件结束。耗时：0:00:13.076516。本文件产出样本数：11
# [396/433] 正在处理文件：POINTdata_106881.json (开始时间: 2025-12-21 16:33:55.136332)
#   -> 文件结束。耗时：0:00:21.903168。本文件产出样本数：11
# [397/433] 正在处理文件：POINTdata_106301.json (开始时间: 2025-12-21 16:34:17.039755)
#   -> 文件结束。耗时：0:00:17.227466。本文件产出样本数：11
# [398/433] 正在处理文件：POINTdata_137688.json (开始时间: 2025-12-21 16:34:34.267304)
#   -> 文件结束。耗时：0:00:15.871611。本文件产出样本数：11
# [399/433] 正在处理文件：POINTdata_100001.json (开始时间: 2025-12-21 16:34:50.139014)
#   -> 文件结束。耗时：0:00:16.848360。本文件产出样本数：11
# [400/433] 正在处理文件：POINTdata_79864.json (开始时间: 2025-12-21 16:35:06.987822)
#   -> 文件结束。耗时：0:00:15.761853。本文件产出样本数：11
# [401/433] 正在处理文件：POINTdata_137759.json (开始时间: 2025-12-21 16:35:22.749761)
#   -> 文件结束。耗时：0:00:17.958388。本文件产出样本数：11
# [402/433] 正在处理文件：POINTdata_137470.json (开始时间: 2025-12-21 16:35:40.708277)
#   -> 文件结束。耗时：0:00:18.077749。本文件产出样本数：11
# [403/433] 正在处理文件：POINTdata_100187.json (开始时间: 2025-12-21 16:35:58.786362)
#   -> 文件结束。耗时：0:00:19.193629。本文件产出样本数：11
# [404/433] 正在处理文件：POINTdata_77010.json (开始时间: 2025-12-21 16:36:17.980075)
#   -> 文件结束。耗时：0:00:13.306815。本文件产出样本数：11
# [405/433] 正在处理文件：POINTdata_137562.json (开始时间: 2025-12-21 16:36:31.287018)
#   -> 文件结束。耗时：0:00:12.751952。本文件产出样本数：11
# [406/433] 正在处理文件：POINTdata_146837.json (开始时间: 2025-12-21 16:36:44.039047)
#   -> 文件结束。耗时：0:00:20.395096。本文件产出样本数：11
# [407/433] 正在处理文件：POINTdata_80128.json (开始时间: 2025-12-21 16:37:04.434481)
#   -> 文件结束。耗时：0:00:09.704988。本文件产出样本数：11
# [408/433] 正在处理文件：POINTdata_58895.json (开始时间: 2025-12-21 16:37:14.139574)
#   -> 文件结束。耗时：0:00:14.966128。本文件产出样本数：11
# [409/433] 正在处理文件：POINTdata_79809.json (开始时间: 2025-12-21 16:37:29.105902)
#   -> 文件结束。耗时：0:00:15.157361。本文件产出样本数：11
# [410/433] 正在处理文件：POINTdata_77952.json (开始时间: 2025-12-21 16:37:44.263347)
#   -> 文件结束。耗时：0:00:15.272673。本文件产出样本数：11
# [411/433] 正在处理文件：POINTdata_99974.json (开始时间: 2025-12-21 16:37:59.536195)
#   -> 文件结束。耗时：0:00:16.242303。本文件产出样本数：11
# [412/433] 正在处理文件：POINTdata_137692.json (开始时间: 2025-12-21 16:38:15.778638)
#   -> 文件结束。耗时：0:00:15.852038。本文件产出样本数：11
# [413/433] 正在处理文件：POINTdata_137738.json (开始时间: 2025-12-21 16:38:31.631060)
#   -> 文件结束。耗时：0:00:18.130429。本文件产出样本数：11
# [414/433] 正在处理文件：POINTdata_77358.json (开始时间: 2025-12-21 16:38:49.761595)
#   -> 文件结束。耗时：0:00:15.683536。本文件产出样本数：11
# [415/433] 正在处理文件：POINTdata_77972.json (开始时间: 2025-12-21 16:39:05.445542)
#   -> 文件结束。耗时：0:00:15.675572。本文件产出样本数：11
# [416/433] 正在处理文件：POINTdata_106462.json (开始时间: 2025-12-21 16:39:21.121211)
#   -> 文件结束。耗时：0:00:17.763303。本文件产出样本数：11
# [417/433] 正在处理文件：POINTdata_106618.json (开始时间: 2025-12-21 16:39:38.884665)
#   -> 文件结束。耗时：0:00:21.247834。本文件产出样本数：11
# [418/433] 正在处理文件：POINTdata_106474.json (开始时间: 2025-12-21 16:40:00.132605)
#   -> 文件结束。耗时：0:00:20.204235。本文件产出样本数：11
# [419/433] 正在处理文件：POINTdata_100261.json (开始时间: 2025-12-21 16:40:20.336922)
#   -> 文件结束。耗时：0:00:15.229328。本文件产出样本数：11
# [420/433] 正在处理文件：POINTdata_99981.json (开始时间: 2025-12-21 16:40:35.566433)
#   -> 文件结束。耗时：0:00:15.339581。本文件产出样本数：11
# [421/433] 正在处理文件：POINTdata_106634.json (开始时间: 2025-12-21 16:40:50.906094)
#   -> 文件结束。耗时：0:00:23.771873。本文件产出样本数：11
# [422/433] 正在处理文件：POINTdata_137755.json (开始时间: 2025-12-21 16:41:14.678063)
#   -> 文件结束。耗时：0:00:17.859692。本文件产出样本数：11
# [423/433] 正在处理文件：POINTdata_79813.json (开始时间: 2025-12-21 16:41:32.538002)
#   -> 文件结束。耗时：0:00:15.645786。本文件产出样本数：11
# [424/433] 正在处理文件：POINTdata_58860.json (开始时间: 2025-12-21 16:41:48.183880)
#   -> 文件结束。耗时：0:00:15.591353。本文件产出样本数：11
# [425/433] 正在处理文件：POINTdata_106726.json (开始时间: 2025-12-21 16:42:03.775376)
#   -> 文件结束。耗时：0:00:21.533315。本文件产出样本数：11
# [426/433] 正在处理文件：POINTdata_100021.json (开始时间: 2025-12-21 16:42:25.308943)
#   -> 文件结束。耗时：0:00:15.603268。本文件产出样本数：11
# [427/433] 正在处理文件：POINTdata_137578.json (开始时间: 2025-12-21 16:42:40.912434)
#   -> 文件结束。耗时：0:00:17.424794。本文件产出样本数：11
# [428/433] 正在处理文件：POINTdata_100037.json (开始时间: 2025-12-21 16:42:58.337316)
#   -> 文件结束。耗时：0:00:15.293584。本文件产出样本数：11
# [429/433] 正在处理文件：POINTdata_100172.json (开始时间: 2025-12-21 16:43:13.631230)
#   -> 文件结束。耗时：0:00:15.166812。本文件产出样本数：11
# [430/433] 正在处理文件：POINTdata_106622.json (开始时间: 2025-12-21 16:43:28.798133)
#   -> 文件结束。耗时：0:00:20.179638。本文件产出样本数：11
# [431/433] 正在处理文件：POINTdata_99997.json (开始时间: 2025-12-21 16:43:48.977851)
#   -> 文件结束。耗时：0:00:15.328140。本文件产出样本数：11
# [432/433] 正在处理文件：POINTdata_99978.json (开始时间: 2025-12-21 16:44:04.306114)
#   -> 文件结束。耗时：0:00:15.036025。本文件产出样本数：11
# [433/433] 正在处理文件：POINTdata_137743.json (开始时间: 2025-12-21 16:44:19.342318)
#   -> 文件结束。耗时：0:00:17.434924。本文件产出样本数：11
#
# ==================================================
# 程序运行结束
# 结束时间: 2025-12-21 16:44:36.784228
# 总运行时间: 1:41:23.354420
# 处理文件总数: 433
# 生成样本总数: 4763
# 结果保存路径: ./data/data_koopman_6.txt
# ==================================================
